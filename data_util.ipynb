# %% [markdown]
# ### build vocabulary

# %%
import jieba
jieba.dt.tmp_dir = './'
jieba.initialize()
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache ./jieba.cache
# Loading model cost 0.571 seconds.
# Prefix dict has been built succesfully.

# %%
class Vocabulary(object):
    def __init__(self, max_lines=10000, min_count=10):
        self.max_lines = max_lines
        self.min_count = min_count
        self.line_counter = 0
        self.closed = False
        self.special_words = [u"PAD", u"START", u"EOS", u"UNK"]
        self.words = []
        self.word2id = {self.words[i]:i for i in range(len(self.words))}
        self.wordcount = {k:1 for k, _ in self.word2id.iteritems()}
        
    def tokenize(self, sentence):
        # if isinstance(sentence, str):
        # sentence = sentence.decode("utf8")
        # assert isinstance(sentence, unicode), "%s is %s, should be unicode" %(sentence, type(sentence))
        return jieba.cut(sentence, cut_all=False) # using jieba cut here
    
    def update(self, sentence):
        assert not self.closed, "already closed, should stop update~"
        for word in self.tokenize(sentence):
            if self.word2id.has_key(word):
                self.wordcount[word] += 1
            else:
                self.words.append(word)
                self.word2id[word] = len(self.words) - 1
                self.wordcount[word] = 1
    
    def build_from_file(self, filename):
        # support filenames ? [filename1, filename2,...]
        for line in open(filename, 'r'):
            self.update(line)
            self.line_counter += 1
            if (self.line_counter > self.max_lines):
                break
        self.shrink()
        self.close()
                
    def shrink(self):
        # shrink the dict by min_count
        self.words = [word for word, freq in self.wordcount.iteritems() if freq >= self.min_count]
        self.word2id = {self.words[i]:i for i in range(len(self.words))}
    
    def close(self):
        self.closed = True
        self.words = self.special_words + self.words # merge specail words
        self.word2id = {self.words[i]:i for i in range(len(self.words))}
    
    def sentence_to_word_ids(self, sentence):
        # it is ugly, but works...
        return map(self.word2id.get, 
                   [word if self.word2id.has_key(word) else u"UNK" for word in self.tokenize(sentence)])
    
    def word_ids_to_sentence(self, word_ids):
        return u"".join(
            [self.words[word_id] if word_id < len(self.words) and word_id >= 0 else u"UNK" 
             for word_id in word_ids])
    
    @property
    def details(self):
        #print u"words: " + u", ".join(self.vocab[0:50]) + u"..." + u"\n"
        info = u"class Vocabulary,  got %d words\n" %(len(self.words))
        info += u"words =【" + u" / ".join(self.words[0:10]) + u"】..." + u"\n"
        info += u"line counter = " + unicode(self.line_counter) + u"\n"
        return info

vocab = Vocabulary()
vocab.build_from_file('small.txt')
print vocab
# Out:
# <__main__.Vocabulary object at 0x7fcf08385290>

# %%
print vocab.words[189]
print len(vocab.words)
# Out:
# 疫情
# 6486

# %%
word_ids = vocab.sentence_to_word_ids("突然宣布在香港实习？")
print word_ids
sentence = vocab.word_ids_to_sentence(word_ids)
print sentence
word_ids = vocab.sentence_to_word_ids(sentence)
print word_ids
# Out:
# [1751, 1733, 5414, 1761, 3, 5753]
# 突然宣布在香港UNK？
# [1751, 1733, 5414, 1761, 3, 5753]

# %%
print len(vocab.words)
for word in vocab.words:
    print word
# Out:
# 6486
# PAD
# START
# EOS
# UNK
# 五线
# 海峡两岸
# 奥迪
# 出来
# 第二
# 还要
# 门票
# 鸣人
# 第五
# 为主
# 科在
# 作弊
# 一是
# 卡拉
# 银子
# 幸运星
# 谈
# 线
# 黑豹
# 反
# 财政厅
# 困境
# 0.506884753704
# 幼童
# 须知
# 万余元
# 世纪
# 0.599535107613
# 起诉
# 西藏
# 线上
# 闹
# 见面会
# 美罗
# 史诗
# 第一
# 经济损失
# 第三
# 中西医
# Max
# 刘飞
# 应
# 抱住
# 公路
# 为了
# 三年
# 事前
# 国脚
# 逼平恒大
# AT&T
# 0.470207974315
# 党员干部
# 钻戒
# 中小城市
# 明确
# 在家
# 18183
# 第六次
# 画质
# 0.926888644695
# 翻译
# 0.847989976406
# 之旅
# 开工
# 漫漫
# 新闻
# 女神
# 探底
# 产品
# 须
# 收回
# 目前
# 上
# 后
# 综艺节目
# 机制
# txt
# 一次
# 批复
# 0.936728239059
# 丈夫
# 伴
# 离
# 据说
# 开局
# 周本顺
# 尔特
# 岗位
# 诊疗
# 占据
# 强调
# 开展
# 90
# 正式
# EDG
# 0.061470988724
# 计委
# 做出
# 为何
# 命案
# 精准
# 0.289149539173
# 节
# 银价
# 爱情
# 市场主体
# 各级
# 意见
# 总统
# 司法
# 木地板
# A
# 0.423862367868
# 生物
# 比利时
# 逾
# 标的
# 奶茶
# 射雕
# 0.353408247232
# 柳州
# 硫酸
# 错误
# wins
# 通常
# 王晓晨
# 变质
# 一栋
# 强大
# 社区
# GSMA
# 挖
# 最帅
# 2020
# 中敏
# 所
# 那个
# 订阅
# 改造
# 基地
# 校长
# 机关
# 媒体
# 在外
# 猪肉
# 砂石
# 首秀
# 追回
# 考试网
# 越
# 帕金森病
# 爸爸
# 0.340383648872
# 姜栋
# 有关
# 魔法师
# 目击
# 封顶
# 突出
# 做到
# 群体
# 电动车
# 开心
# 懂
# 医改
# 秋景
# 闰土
# 成都
# 司机
# 副校长
# 全部
# 秒
# 周围
# 连
# 0.886992633343
# 市政府
# 群众
# 驻
# 0.435768723488
# 好
# 重甲套
# 刘恺威
# 或
# 176
# 第七版
# 疫情
# 异客
# BRAIN
# 斯
# 功夫
# 0.573544807732
# 随后
# 萝卜
# 外媒
# 牵手
# 开幕
# 解除
# 突发
# 沈部
# 各类
# 十二五
# 厂长
# 讨论
# 包容
# 晴川
# 」
# 亲戚
# 行驶
# ３
# 开庭
# 记
# 吨重
# 春梦
# 0.782162070274
# 不饱和
# 当
# 赫雷斯
# 办公厅
# 马龙
# 卧蚕
# 幸亏
# 内维尔
# 解锁
# 维和部队
# 失控
# 0.83428299427
# 思思
# 丢
# 童车
# 年前
# 机场
# ‘
# 卡曼
# 微博晒
# 0.567690312862
# 天上
# 发酵
# 案
# 打印
# 秘密
# 义诊
# 日常
# X
# 保税
# 0.514190018177
# 确认
# 阿勒泰市
# 精品
# 观点
# 科协
# 学校
# PS3
# PS4
# 错身
# 天
# 因某
# 我们
# 0.895489215851
# 立式
# 何锋
# 网上
# 抢装潮
# 超越
# 开始
# 家人
# 微博
# 增肌
# 0.903439283371
# 红军
# 出谋划策
# 思想
# 兼
# 泰
# 访
# 清茶
# 股神
# 改革
# 中敏队
# IP
# 背景
# 水库
# 同样
# 令人
# BlockB
# 0.399505496025
# 能源
# 西游
# .
# 发送
# 支出
# 白沙县
# 曲线
# 约翰逊
# 隆尧县
# 卫视
# 过
# 0.951200187206
# 走失
# 复旦大学
# 全面
# 汽摩
# 古城
# TDI
# 胸腔镜
# 出战
# 脱贫
# 在建
# 代表
# 原题
# 冰岛
# 强度
# LOL
# 保监会
# 劝导
# 取得
# 力争
# 得益于
# 移动
# 研讨会
# 功德
# 沈阳
# 警车
# 深港
# 报复
# 没想到
# 汉江
# 前面
# 降
# 错过
# 神界
# 0.14238397617
# 5.75
# 策略
# 韩版
# 干政
# 福山区
# 药
# 困难户
# 净化
# 计价
# 悲喜
# 狗狗
# 智能
# 些
# 免去
# 无往
# 本钢
# 北京
# 超载
# 丰
# 文章
# ％
# 同步
# 主人
# 征程
# 0.873020350933
# 0.321566194296
# 拿到
# 案二审
# 宝石
# 据
# 品味
# 小蜜
# 肉制品
# 签
# 赔偿
# 辆
# 超过
# 重甲
# 和
# 信号
# 医学会
# 尴尬
# 长期
# 减脂
# Facebook
# 异常
# 长江路
# 主角
# 镍
# 倒车
# dnf
# 0.328618496656
# 因
# 六项
# 0.435459971428
# 农场
# 同比
# 我市
# 省
# 主干
# 今年年底
# 0.85350137949
# 验证
# 东汉
# 警官
# 0.427728652954
# 第三季度
# 强烈
# 登场
# 雷鸟
# 杀
# 收入
# 博览会
# 抓获
# 界
# 量
# 巨头
# 身上
# 兑换
# 0.933895349503
# 要素
# 呢
# 一款
# 警察
# 技能
# 踩点
# 150
# 0.515700221062
# 看
# 遭遇
# 罚球
# 法庭
# 打火机
# 涉及
# 长春
# 上市
# 主体
# 诊所
# 0.852724373341
# 前锋
# 争端
# 姜洪
# 8686u
# 左右
# 公安部
# 器件
# 边
# 有名
# 肯定
# 部督
# 0.404666543007
# 三处
# 家务活
# 代言
# 第四天
# 国土
# 这位
# 反映
# 以为
# 被免
# 漂
# 日前
# 重返
# 撞衫
# 肢体
# 强化
# 0.919554769993
# 离职
# 一所
# 财产
# 记录
# 一手
# 险些
# 近照
# 拨付
# 0.49782597969
# 平台
# 查封
# 0.908577024937
# 晨光
# 阿怡代
# 出演
# 设
# 0.247294083238
# 0.740600168705
# 一把
# 知识产权
# M1
# 匆匆
# 0.901560366154
# 内容摘要
# 号
# 参与
# 年底
# 同时
# 306
# 生活圈
# 公安
# 总是
# 甘肃
# MC
# 后付费
# 刷量
# 更
# 年度
# 推送
# 变得
# 这么
# 男篮
# 捉妖
# 强制
# 搞
# 真容
# 古宅
# 开启
# 基层
# 冷汗
# 江苏省
# 栽参
# 安置
# 协会
# 神秘
# 正在
# 粉丝
# 罗志祥
# 美联储
# 国庆节
# 毫无
# 东北地区
# 凤凰
# 这个
# 生出
# 蜀山
# 今报
# 0.858463585377
# 万吨
# BAT
# 指
# 完
# 强势
# 采砂
# 未来
# 230
# 强劲
# 风光
# 伤病
# 0.744791567326
# 模特儿
# 强力
# 关晓彤
# Why
# 制版
# 0.395662784576
# 主帅
# 空气
# 这些
# 开着车
# 0.296717047691
# 批准
# 好评
# 测试
# 国行
# 传言
# 万块
# 纪
# 考驾照
# 朴槿惠
# 分钟
# 继续
# 0.847309887409
# “
# 保险业
# 0.875667989254
# 午间
# 同期
# 古墓
# 吐舌
# 霾
# 一段
# 龙背
# 联想
# 发
# 0.593700304627
# 教师
# 0.892344594002
# 0.583725849787
# 啪
# 上台
# 潮
# 洞庭湖
# 风力
# 大山深处
# 上古
# 基弗
# 五体投地
# 交警
# 0.914784312248
# 记者
# 最美
# 无人
# P2P
# 小说
# 动车
# 稳居
# 金价
# 九江
# 春节
# 路上车
# 大规模
# 计划
# 家
# 充电
# 克
# 受贿案
# 先是
# 上单
# 可乐
# 弟子
# 全日制
# 0.369321227074
# 中方
# 交通
# 0.419806540012
# 车手
# 0.614580492179
# 在内
# 马尔代夫
# 若干意见
# 根特
# 单身
# 紧紧围绕
# 营收
# 肝
# 资金
# 业绩
# 受不了
# 2
# 水储
# 投资
# 势头
# 白百何
# 0.403349548578
# 畔
# 异变
# 海马
# 习近平
# 英
# 入门级
# 胡润
# 巨
# 铁饼
# 弄影
# 总数
# 生化
# 世界
# 驾驶
# 王立
# 老赖
# 克拉克
# 0.553105175495
# 智能手机
# 亮
# 崇左
# 付费
# 金融信息
# 范围
# 租借
# 卷
# 最终
# 艾利
# 加速器
# 作品
# 29
# 身患
# 照
# 大连
# 朋友
# 领导人
# 长
# 劳模
# 国足
# 药监局
# 万元
# 大亨
# 概念
# 0.765740036964
# 同意
# 开瓶
# 讲座
# 自有
# 景点
# 多云到阴
# 肆虐
# 著名
# 夹
# 激化
# 科学
# 剧中
# 啦
# 建厅
# 韩服
# 直接
# 自杀
# 进京
# 小路
# 试炼
# 需要
# 试点
# 供应
# 停办
# 娱乐圈
# 之机
# 护栏
# 添新彩
# 项目
# 开普敦
# 体验
# 0.55026859045
# 全
# 发不出
# 转型
# 先锋
# 0.597060918808
# 道路
# 短时
# 三分
# 东兰县
# 生命
# 遇到
# 研发
# 0.863632678986
# 异味
# 她
# 马铃薯
# 陨落
# 搭配
# 被告
# 田朴珺
# 纱织
# 周中
# 一期
# 广场
# 长沙
# 周三
# 周一
# 坠亡告
# 一样
# 稳定
# 荣誉
# 删减
# 0.332462489605
# 骗局
# 曝
# 精工
# 传来
# 一条
# 0.957482755184
# 查处
# RUE
# 统计
# 儿科
# 之梦
# 0.346321642399
# 0.802677512169
# 南瓜
# 13.0
# 昨日
# 大众
# 曼联
# 白云
# 0.234848303099
# 大会
# 周五
# 无名
# 今晨
# 周二
# 收官
# 慰问
# 形象
# 大使
# 请问
# 修
# 新风
# 捷豹
# 即使
# 激励
# 上周
# 高峰论坛
# 从众
# 掉
# 小车
# 激光
# 我国
# 重大
# 老公
# 只要
# 催生
# 收银员
# 选择
# 0.901977539062
# 今日
# 杨文增
# 黑色
# 博览
# 0.498379528522
# 美照
# 10.57
# 球队
# 伸至
# 0.581695248683
# 0.951647460461
# 严格执行
# 反恐
# 借伞
# 臭
# 近万名
# 传说
# 晋江
# 0.158690413892
# 广东
# 刘雯
# 归母
# 通关
# 0.908685147762
# 扶贫
# 机巡
# 丽泽桥
# 开发
# 御空
# 座谈会
# Kyson
# 副领队
# 基础
# 公积金
# 太快
# 归属于
# 头疼
# 险胜
# 片场
# 全面实施
# 亿元
# 东丽区
# 0.562959313393
# 丹尼
# 替补
# 疏松
# 楼市
# 保卫
# 31.0
# 0.616848478715
# 传送门
# ＋
# 削减
# 0.394205421209
# 变成
# 料车
# 非洲
# 异地
# 0.267359435558
# 登陆
# 法国
# 新闻局
# 部署
# 新高
# 精彩
# 两次
# 比勒陀利亚
# 桂冠
# 加快
# 难度
# 总结
# 系列
# 炫
# 大力
# 0.570790350437
# 兴奋剂
# 对接
# 7263.36
# 降价
# 秋瓷
# 小企业
# 首次
# 三人
# 电子商务
# 心平气和
# 实在
# 抵京
# 这场
# 核心
# 馆
# 斯科特
# 降临
# 0.853592216969
# 看起来
# 卡片
# 卡牌
# 具有
# 最新
# 改
# 预告
# 亿人
# 留言
# 工程学院
# 越秀区
# 加强
# 一站
# 需谨慎
# 所以
# 廉价
# 获得
# 三个
# 武汉
# 经销商
# 萎缩
# 作业
# Lucky
# 高速公路
# 周四
# 纯
# 原谅
# 概要
# 股
# 前后脚
# 0.861403822899
# 作为
# 渔民
# 金币
# 大厅
# 帕拉
# 港珠澳
# 6
# 已成
# 标普
# 多时
# 厕所
# 究竟
# 0.227299356717
# 资讯
# 大叔
# 澳洲
# 皮会
# 希望
# 即可
# 亲热
# Mustang
# Panasonic
# 、
# 换档
# 开发区
# 锦衣
# 北大
# 碳酸锂
# 马路
# 聚焦
# 光电
# 估值
# 食品药品
# 重阳节
# 诗剧
# 狂
# 演出
# 车祸
# 刘涛
# 0.891013205051
# 大卖
# 与众不同
# 几十分之一
# 降低
# 受贿
# 0.799514293671
# 称
# 捣毁
# 综合
# 普及
# 路上
# 那堪
# 处理
# 11.0
# 最有
# 万佛
# 而
# 园林
# 阻拦
# 考虑
# 飞机
# 高亚麟
# Kimi
# 只有
# 三百万元
# 万众
# 评选
# 周六
# 负担
# 败光
# 郭富城
# IPO
# 拍卖
# 带领
# 本能
# 培训班
# 保险公司
# 菜鸟
# NGK
# 0.467451263219
# 伦敦
# 20.0
# 撤
# 承担
# 珠海
# 阵雨
# 男性
# 阴阳师
# 全能
# 卖
# 0.568164920807
# 乡亲们
# 回落
# 李敏
# 医生
# 自治区
# 制造
# 天天
# 只是
# 柯桥区
# 0.84451842308
# 马车
# 阿瓜
# 战斗
# 0.310972511768
# 放松
# 进军
# 人民政府
# 叫
# 南怀瑾
# 湾
# 往昔
# 维稳
# 深情
# 斤
# 都兰县
# 多条
# 进入
# 0.280769318342
# M
# 习惯
# 一种
# 康县
# 百渡
# 世界纪录
# 猎艳
# 大全
# 驻湘
# 万人
# 局地
# 郁闷
# 0.884578168392
# 0.841706156731
# 威胁
# 黑车
# 代谢性
# 演讲比赛
# 小镇
# 破获
# 北方
# 申请
# 犯
# 南海
# 加拿大
# 北岸
# 海阳市
# 洗髓经
# 总
# 参加
# 演员
# 0.855749487877
# 乡音
# 0.768623411655
# 0.910419940948
# Decor
# 戏
# 较为
# 刘先生
# Vive
# 公信力
# 水体
# 出现
# 板材
# 露出
# 济南市
# 男星
# 将
# 水井
# 状况
# 侧
# 毒品
# 环
# 0.695773094893
# 空气污染
# 大型
# 陈若仪
# 应对
# 0.7296230793
# 受伤
# 德阳
# 塞
# 线路
# 那么
# 率达
# 常见
# 可
# 住院
# 果加
# 32
# 吸毒
# 投入使用
# 质疑
# 0.970319330692
# 400
# 校花
# 34
# 裸尸案
# 入手
# 古天乐
# 听证
# 引进外资
# 榜
# 那些
# 新股
# 力度
# 2030
# 元
# 实力
# 第三次
# 安排
# 钛白粉
# 负敏
# 布朗特
# 0.58
# 在于
# 要求
# 较量
# 刚过
# 王石
# 0.0934042176232
# 戈麦斯
# 50.0
# 看好
# 贸易协定
# 让
# 听
# 开幕式
# 0.582396787405
# 生产
# 菜
# 竞赛
# 遗址
# 人气
# 告上
# 党
# 管廊
# 人民
# 县委
# 出院
# 风云
# 市场价
# 体育
# Myethos
# 巨大
# 怎样
# 大腿
# 汇报
# 物流
# 最低
# 加大
# 挂牌
# 妇女
# 当时
# 细分
# 敦豪
# 分行
# 主席
# 回击
# 混凝土
# 快递
# 未被发现
# 售价
# 需
# 红色
# 培育
# 台风
# 推进
# Smartisan
# :
# 妖精
# 风俗
# 徘徊
# 着
# 殷
# 用户
# 否认
# 觉得
# 做
# 似乎
# 男方
# 0.710471987724
# GDP
# 剧场版
# 哭泣
# 0.574478214979
# 净利
# 累计
# 失眠
# 坍塌
# 0.770552992821
# 当前
# 笔记
# 则
# 骑士
# 上万
# 热门
# 0.86873292923
# 举办
# 0.355229377747
# 指导
# 纠葛
# 执行
# 联手
# 打响
# 异位
# 指定
# 歌
# 产业园
# 亡灵
# 变
# 税务
# 出炉
# 资质
# 国际
# 向
# 离家出走
# 西
# CPI
# 刹车
# 仙剑
# ：
# 百日
# 打伤
# 未
# 维修
# 伪造
# 团队
# 一片
# F1
# 回归
# 0.967753112316
# 0.292979980508
# 第四轮
# 刷新
# 入学考试
# 鸣囊
# 早
# 微信
# 穿梭
# 世贸组织
# 困难
# 按照
# 竟当
# 汽车尾气
# 肥胖
# 0.814822018147
# 亿万富豪
# 598
# 坚持
# 马蓉
# GT350
# 队
# 校区
# 洗手间
# 老鹰
# 罚款
# 年代
# 保暖
# 安源
# 0.903676331043
# 牵动
# 星期四
# 0.807207047939
# 令
# 共
# 区域
# 稳中
# 拼
# 大家
# 直盘
# 儿时
# 临沂
# 聚钱
# 大宗
# 犯罪
# 及时
# 解放军
# 抱团
# 首批
# 陆良
# 握手言和
# 年会
# 美景
# 王宝强
# 变电站
# 0.516421115398
# 处罚
# baby
# 眼袋
# 康复
# 征收
# 网友
# 家务
# 备受
# 起到
# 回应
# 广大
# 深爱
# 学生
# 张学友
# 发布公告
# 小鸡
# 节点
# 儿浴照
# 升
# 住
# Q
# 大学
# 年收入
# 杭州
# 自拍女
# 拳打脚踢
# 控制性
# 零碎
# 并且
# 光棍节
# 根据
# 0.637587949634
# 大衣
# 高智商
# 冲突
# 支付
# 王健林
# 开门红
# 力
# 白天
# 0.902393639088
# 时候未到
# 想到
# 然而
# 产业
# 0.544615462422
# 到
# 泥泞
# 2018
# 2015
# 2014
# 2017
# 2016
# 产下
# 2012
# 效果
# 亨斯迈
# 涨
# 人
# 继
# 登革热
# FABITORIA
# 主办
# 渔村
# 邀请
# 唐冶
# 易
# 比照
# 燃气
# 暨
# 巨怒
# 之美
# 微
# Store
# 纵火
# 合肥
# 假
# 0.921324431896
# 花生
# 所谓
# 丢失
# 文明
# 没收
# 花田
# 股权
# 漫画
# 不明飞行物
# 分
# 爆料
# 与
# 1000
# 助力
# 骗术
# 拒绝
# 欢迎
# 亲
# 仪式
# 全国总工会
# 五条
# 天养
# 严正声明
# 物品
# 腾讯
# 给
# 0.545236647129
# 东方红
# 航天
# 坐骑
# 省级
# 无聊
# 监管局
# 能
# 退换货
# 大大
# 吸收
# 推荐
# 婚礼
# 名校
# 编制
# 轻松
# 修养
# 再续
# 版本
# 旗舰
# 培训
# EXO
# 预增
# 事件
# 爱上
# 卡组
# 本身
# 机会
# 0.830656170845
# 品牌战略
# 电通
# 后续
# 信访工作
# 古代
# 即日起
# 冯小刚
# 跌幅
# 氛围
# 0.852390468121
# 亮相
# 操作
# 公里
# 昆士兰州
# 称赞
# 龙
# 第三批
# 0.757921665907
# 您
# 炉石
# 由
# 获取
# 赔礼道歉
# 高鸿
# 股票
# 孟宪东
# 0.478954285383
# 近日
# 0.908329367638
# 曝新
# 从市
# 山东省
# 保护
# 大幅
# 一直
# 昨
# 级风
# 这家
# 司长
# 区别
# 高龄
# 得
# 金利
# 原
# 8.0
# 财富
# 金刚
# 有些
# 焦作
# 焦点
# 仍
# 明日
# 获利
# 菏泽
# 地铁
# 保持
# 发表
# 婚
# 趋势
# 广州
# 常熟市
# 0.333182215691
# 擅自
# 曝携
# 获刑
# 发行
# 巨制
# 预告片
# 货币量
# 0.894614696503
# 经营
# 一瞥
# 中国保监会
# 指出
# 例行
# 陈赫
# 卡罗
# 尿血
# 再度
# 单项
# 均
# 有力
# 罗
# 还是
# 翘楚
# asked
# 网址
# 师门
# 7.73
# 出装
# 0.183012479295
# 头条
# 0.963238298893
# 召唤师
# 3100
# 点击
# 型号
# 克苏恩
# 近期
# 省委书记
# 利
# 济宁
# 宝鸡
# 版
# 省公安厅
# 但丁
# 战队
# 贸易
# 末日
# 中通
# 政府
# 0.820321261883
# 离队
# 独家
# 委员会
# 黄岩岛
# 幻城
# 英文
# 进展
# 官渡区
# 城手游
# 网吧
# 安检
# 截止
# 首日
# 冲动
# 秦皇岛
# 乡村
# 调侃
# 0.927998900414
# 面额
# 南极
# 之
# 招生
# 依托
# 纷纷
# 0.311785906553
# 0.365946829319
# 比肩
# 发言人
# 25.0
# 登录
# 种植
# 城阳区
# 一瓶
# 综合治理
# 指南
# 定位
# 包疯传
# 饼干
# 口语
# 0.531728539616
# 济州岛
# 雷德
# 总决赛
# 领导品牌
# 南宁市
# 而且
# 9.0
# 主城
# 湖景区
# 0.752604186535
# 站
# 满
# 刺
# 商贸
# 快
# 安委会
# 往
# 搁浅
# Ovum
# 改不改
# 观后感
# 马拉松
# 毛泽东
# 考试
# Fami
# 推
# Khara
# 一段时间
# ~
# 受理
# 儿
# 农业
# 上市公司
# 海滩
# 抱怨
# 肺癌
# 正
# 节目
# 首播
# 铁路
# 纪委
# 起
# 腿
# 降级
# 星美
# 坚定
# 江若琳
# 敲诈
# 朱婷
# 坠下
# 领航
# 海天
# 0.770057678223
# 屁股
# 史
# 品牌
# 科
# 发放
# 一点
# 告破
# 罪
# 大招
# 猝死
# 陕西
# 其
# 绿
# 晚上
# 条件
# 首富
# 队伍
# 0.776740193367
# 配方
# +
# 大战
# 名单
# 徽商
# 入室
# 对外贸易
# 香水
# 0.9240000844
# 五年
# 三审
# 骨质
# 本报
# 罚单
# 71.75
# 也
# 角逐
# 收益
# 证监会
# 首家
# 保险行业
# 它们
# 健康状况
# 最后
# 0.489724963903
# 区间
# 入围
# 广东省
# 阳泉市
# 普惠
# 男友
# 穿越
# 赶忙
# 锤子
# 依法
# 71.0
# 功能
# 晚
# 这是
# 国务院新闻办
# 老
# 明天
# 欧洲
# 欧派
# 查出
# 周报
# 日蓝贴
# 0.679122924805
# 龙术
# 平稳
# 著称
# 吹
# 吸引
# 0.860746324062
# 鼎山
# 科目
# 善良
# 总会
# 专利
# 锐减
# 名列
# 决议
# 揪心
# 虽然
# 0.544736755779
# 再
# 「
# 实效
# 同伴
# 12.0
# 6.0
# 备案
# 宣布
# 华盛顿
# 结局
# 下降
# 认证
# 印象
# 气质
# 韩国政府
# 采取
# 旅
# 导线
# 背包
# 才能
# 透露
# 0.782181739807
# 印谱
# 1.05
# UAG3000
# 突然
# 贵州
# 环评
# 策划
# 0.518515339494
# 天梯
# 收费
# 决裂
# 米易县
# 冰箱
# 香港
# 莱芜市
# 第三届
# 路线
# 剧情
# 暴涨
# 国家旅游局
# 部分
# 年
# 百强
# 南宁
# 城
# 学习
# 巫毒
# 驴肉
# 宝华
# 实施
# 选举
# 0.398481965065
# 听闻
# 聊得
# 报道
# 下面
# 上半年
# 0.969277262688
# 好多
# 美国国防部
# 0.536412844062
# 冷
# 空姐
# 民族
# 强硬
# 研究生
# 中心组
# 跟
# 有点
# 查看
# 金江
# 展览
# 大妈
# 牛肉
# 外遭
# 需求预测
# 预期
# 受阻
# 北欧
# 0.758812308311
# 股市
# 两成
# 不降
# 大话西游
# 学会
# 同事
# 0.856516301632
# 过剩
# 色彩
# 报酬
# 郭德纲
# Lucy
# 同价
# 时许
# 财政
# QQ
# QS
# 800
# 岁成
# 机器人
# 四岁
# 哪里
# 压成
# 伤得
# 嗜杀成性
# 多地
# KWAVE
# 一一
# 芯片
# 0.536534786224
# 44.28
# 7.0
# 7.1
# 随时
# 真的
# 扎克
# 级
# 一个
# 0.428634554148
# 主任
# 其他
# 创始人
# 一死
# 财报
# 美学
# 鲸鱼
# 周来
# 首张
# 争夺
# 真相
# 菲律宾
# 医疗保健
# 0.845543146133
# 安利
# 最具
# 系
# 十一
# 万
# 十三
# 霍
# 点此
# 居民家庭
# 美容
# 阶段
# 战
# 一些
# 儿童
# 状态
# 一人
# 内测
# 委员
# 0.266055566569
# 其中
# 0.367776930332
# Mangli
# 一件
# 红七军
# 就让
# 自主
# 有益
# ETF
# 名图
# 胡春华
# 本
# 孵化器
# 多出
# 实战
# 场景
# 研究
# 一位
# 0.458892999139
# 0.18
# 丰富
# 拍摄
# 经过
# 奇幻
# 首席
# 0.763281643391
# 血液
# 走
# 侵犯
# 飞抵
# 护花使者
# 玛莎拉蒂
# 结构
# 水产品
# 凯文
# 戴尔
# 外籍
# 高云
# 0.149884602241
# 问
# 无忧
# 稀
# 印说
# 0.842109084129
# 总冠军
# 暂时
# 土地
# 硬
# 女主角
# 0.294719785452
# 商报
# 放出
# 在线
# 喝止
# 教会
# 矿山
# 上门服务
# 身亡
# 首度
# 细节
# 1970
# Gorillaz
# 孩子
# 东京
# 未能
# 正确
# 0.265724420547
# 0.714273929596
# 金融市场
# 等于
# 承办
# 太
# 天气
# 艾翁
# 围绕
# iOS
# S6
# 整容
# 美好
# 美女
# 骗婚
# 厄运
# 泼
# 物价局
# 天内
# 姜子牙
# 余人
# 投资者
# 脸乱敏
# 会展业
# 明显
# 标准
# 举措
# 价值
# 没有
# 0.932195365429
# 相遇
# /
# 车上
# 园区
# 汇
# 就要
# 最受
# 拘
# 0.156886023663
# 判官
# 储备
# 人民币
# 0.685133993626
# 首届
# 化妆品
# 收服
# 天津
# 最初
# 金树
# 达蒙
# 上线
# 21.0
# 供电
# 带
# 爱立信
# 安全
# 早前
# 喷
# 听花
# 载人
# 0.197149456479
# 丁次
# 0.85165309906
# 艾米莉
# 迪普
# 首尔
# 骗子
# 进
# 0.905269145966
# 堵车
# 水系
# 诽谤
# 河北省
# 是不是
# 业务
# 轰
# 金白银
# 奖学金
# 煤炭
# 者
# 收跌
# 方面
# 范冰冰
# 李晓霞
# 举报
# 深井
# 群聊
# 留守
# 儿子
# 汉中
# 特辑
# 灰色
# 属性
# 无处不在
# 定西市
# 世外
# 伤害
# 释放
# !
# 主演
# 平米
# 走访
# 的话
# 特
# 司
# 曾
# 海洋
# 深化改革
# 严格
# 当中
# 会
# 曝光
# 香港股市
# 受其
# 通知
# 蜘蛛网
# 活跃
# 党内
# 金服
# 0.871821582317
# 各地
# 座谈
# 0.853345572948
# 临川
# 服务
# 多岁
# 备战
# 顾奋渊
# 家装
# 哪个
# 班主任
# 排行榜
# 依旧
# 冷暖空调
# 运营商
# 引领
# 处于
# 少年
# 首发
# 0.923902451992
# 火影忍者
# 流通
# 排骨
# 甩
# 增多
# 曝出
# 名字
# 扇
# 而是
# 当代
# 多少
# 七五
# 菲
# 年纪
# 嗜血
# 答记者问
# 翔
# 战仅积
# 每股
# 听证会
# 舞
# 指数
# 信息化
# 为期
# 朴
# 0.202322293818
# 经济网
# 虾米
# 武宁
# 跟随
# 昌平
# 共用
# 烈焰
# 优缺点
# 部委
# 航天航空
# 监测
# 宓冬莹
# 式
# 出任
# 0.44189530611
# 巨星
# 邦
# 四分
# 关键
# 男子
# 预测
# 美团
# 参演
# 永恒
# 美国
# 弯弓
# 神奇
# 安徽
# 精神
# 主意
# 叼
# 摔跤手
# 负责人
# 提起
# 首先
# 猛料
# 助推
# 有种
# 双驰
# 包括
# 版图
# 报名条件
# 雨夹雪
# 销售
# 邮报
# 集团
# 最强
# 龙河
# 作用
# 开着
# 种
# 高新技术
# 现身
# 提质
# 特色
# 0.959906697273
# SUV
# 上班
# 22.0
# 之余
# 隐藏
# 措施
# 纽特
# 小
# 重要讲话
# 主打
# 隆重举行
# 亏损
# 多年
# 注定
# 所有
# 打通
# 环境
# 购房者
# 话题
# 唯一
# 前所未有
# 大桥
# 断崖
# 武器
# 王女士
# 栋梁
# 货车
# 0.894560754299
# 516
# 较
# 等待
# 0.816664814949
# 之一
# 患者
# 跳水
# 花
# 去
# 省份
# 军民结合
# 办结
# 城步
# 哈
# 老年人
# 0.81908094883
# 男主腹
# 克劳
# 世界贸易组织
# 突破
# 英语
# 江西
# 栏目
# 管理工作
# 克斯
# 0.828055143356
# 保温杯
# 官网
# 受邀
# 良好
# 欣然
# 成长
# 开盘
# ]
# 鸟类
# 宣城
# 口红
# 撩汉
# 0.873938202858
# 主持
# 沙漠
# 雾
# 0.951108217239
# 赢家
# 回家
# 226
# 支公司
# 延长
# 卫队
# 最大
# 心疼
# 唐朝
# 旅游
# 叶县
# 砸
# 路子
# 可防
# NBA15
# 政治
# 彩墨
# 这次
# 海南
# 可达
# 想
# 协作
# 全场
# 微博上
# 最好
# 消防通道
# 拼装
# 鲤鱼
# 朝
# 刘强
# 网易
# 0.153063391149
# 除了
# 中央气象台
# 3
# 越来越
# 限制
# 海岛
# 供给
# 赶到
# 华人
# 新闻网
# 人事部门
# 火车
# 影迷
# 们
# 玉山
# 中级法院
# 严峻
# 史家
# 酒驾
# 湖南
# 湛江
# 0.363313764334
# 凯洛
# 水源地
# 主旨
# 普法
# 获批
# 征求意见
# 武器装备
# 姑娘
# 监督管理
# 德
# 最堵
# 眼
# 县
# 应援
# 五成
# 婴幼儿
# 0.0983684578445
# 汇率
# 标准化
# 转
# 扎堆
# 实体
# 没法
# 黄金周
# 谁
# 一次性
#
# 充分
# 必要
# 出售
# 孙红雷
# 父亲
# 大漠
# 对阵
# 室
# 及其
# 身处
# 中
# 后会
# 邮政
# 人巡
# 密码
# 多多
# 事业
# 风电
# 名市
# 机组
# 名师
# 加成
# 一个月
# 只
# 交通运输
# 大河
# 山东
# 市
# 登革热病
# 淘金
# 盐湖
# 秒杀
# 0.13518846035
# 萌
# 护肤
# 0.217362712862
# 闹翻
# 0.366921454668
# 0.742162168026
# 解读
# 美元
# 0.125401301842
# 庭外和解
# 电视
# 冲上
# 热血
# 戏里
# 规划设计
# 若干
# 现金
# 鄂伦春
# 伤势
# 一项
# 驻南
# 吃喝玩乐
# 指报
# 伯格
# 33.0
# 暴怒
# 打破
# 筹到
# 观察
# 市属
# 生物医药
# 魔幻
# 年内
# 科研
# 国民党
# 奥运
# lol
# 闪耀
# 权贵
# 热情
# 拉
# J
# 坐
# 日电
# 揭秘
# 邮轮
# 并
# 多家
# 这样
# 厌倦
# 少女
# 红富士
# 激烈
# 红九军
# 被盗
# 滴血
# 知识
# 白沙
# 阴到
# 主权
# 景区
# 龙华区
# 告知
# 南国
# 黄金
# 文化
# 加急
# 凌馨
# 男生
# 越野
# 获悉
# 我省
# 看到
# 宁德
# 上榜
# 伤者
# 北极星
# 冲刺
#
# 经验
# 接待
# 杜特
# 监理
# 亿
# 各位
# 变阵
# 节奏
# 有人
# 境外
# 乔
# 出场
# 支撑
# 换
# 工作力度
# 网站
# 披露
# 惨烈
# 勇士
# 0.337459504604
# 黎素梅
# 吃
# 的
# 媒体报道
# 自家
# 降温
# 明星
# 五个
# 莫高窟
# 侵权
# 打小报告
# 盘中
# 天窗
# 千亿
# 涨幅
# 老家
# 流行
# 0.96022850275
# 风格
# 冠军
# 炮塔
# 0.58026554063
# 怎么
# 男皮甲
# 转让
# 大片
# 当场
# 初显
# 当地
# 炫舞结
# 美丽
# 0.975559234619
# 反弹
# 暴力
# 欢乐颂
# 各个
# 不档
# B轮
# 个
# 之后
# 效果图
# 梅西
# 苹果
# 款式
# 便
# 华南
# 年期
# 0.133017253131
# 拍
# 昨天
# 泡茶
# 雨后春笋
# 县政
# 红十字
# SS
# ST
# 官方
# 线缆
# 总经理
# 其实
# 华北
# 送
# 车头
# 三季度
# 0.219323858619
# 一定
# 有所
# 网第
# 户籍
# 泰国
# 教学
# 一家
# 上校
# 后卫
# 由头
# 衡阳
# 南
# 贷款
# 余天
# 触角
# 化工行业
# 0.91494089365
# 瞬间
# 胶
# 长假
# 文化交流
# 什么
# 阿修罗
# MIX
# 之地
# 化
# 0.623363524675
# 文件
# 事情
# 现货
# 基本
# 共商
# 病
# 0.699844539165
# 0.866298794746
# 福州市
# 真情
# 根治术
# ～
# 黄晓明
# 问石
# 俩
# 张月
# 实用
# 总收入
# 0.406629234552
# 胜利
# 0.907296001911
# 渴望
# 角色
# 步步
# 深夜
# 0.843041419983
# 英寸
# 挡
# 百余
# 能够
# 报考
# 7
# 0.780115008354
# 自如
# 汉子
# 问题
# 有意
# 连胜
# 0.120039674841
# 同志
# 0.961131036282
# 今天
# 李钟
# 武义
# 集中
# 是因为
# 修正
# 篮球队
# 批次
# 宣传
# 百件
# 贡献
# 剧照
# 刘郎
# 妻子
# 一大
# 林洁
# 一天
# 运行
# 特斯拉
# 虎
# 法
# 两天
# 股份
# 陶昕然
# 女孩子
# 诺娃
# 金投赏
# 0.958588838577
# 集体
# 人机
# 嫉妒
# 两大
# 制造业
# 十大
# 出品
# 皮
# 7500
# 股东
# 万股
# 粤西
# 肌腱
# 双星
# 辽宁省
# 导演
# 汤显祖
# 生死
# 农贸市场
# 山口
# 百万
# 厅
# 来自
# 蒋
# 首位
# Note7
# 网红
# 颁奖
# 融资
# 当初
# 安徽省
# 上涨
# 阅读
# 知道
# 动员大会
# 夫妇
# 健身
# 零售
# 血管
# 一幕
# 神
# 巴黎
# 双胞胎
# 雷军
# 材料
# 周年
# 网络
# 大盘
# 驴
# 一年
# 供暖
# 出口
# 蒋劲夫
# 0.571703394254
# 出台
# 一度
# 深山
# 机构
# 火车站
# 现象
# 0.721698522568
# 空中
# 有望
# 今天下午
# 逼入
# 辟谣
# 0.916230738163
# 第五部
# 倡导
# 维持
# 运输
# 车展
# 实现
# 上海
# 四梦
# 圈内
# 歌舞
# 治病
# 秋冬
# 不能
# 一张
# Guerrero
# 几个
# 不胜
# 0.7691385746
# 实验室
# 坐牢
# 人大常委会
# 龙珠
# 首个
# 停止
# 无法
# 维护
# 轰炸机
# 曹云金
# 法治
# 裁定
# 数量
# 生活
# 今年
# 勾结
# 就
# 科技
# 首任
# 丽
# 允儿
# 垃圾
# 英镑
# 0.202839391927
# 捏
# 满足
# 块
# 河蚌
# 反导
# 反对
# 变数
# 15.0
# 无
# 物业
# 假日
# 羡慕
# 震撼
# 高中
# 楼顶
# 内
# 轮胎
# 0.877514958382
# 管线
# 出关
# 改革开放
# 0.496949911118
# 缴纳
# 无人机
# 雅漾
# 车床
# 乐
# 张一山
# 英雄
# 大使馆
# 食
# 0.246979157958
# 柯桥
# CFTC
# 密探
# 再生
# 但是
# 0.559262838629
# 属于
# 农村
# 上演
# 松山
# 有效
# 有限公司
# 0.763388335705
# 看秀
# 随着
# 0.669546246529
# 反增
# 监狱
# 布里斯班
# 自己
# 延边
# 高峰
# 什刹海
# 提醒
# 内容
# 消息
# 假期
# 北美
# 至少
# 70
# 0.406964348815
# 0.750772953033
# 设计师
# 之刃
# 协同
# 0.874279797077
# 反复
# 变速箱
# 模块化
# 剑灵
# 泊位
# 背后
# 期间
# 提速
# 之前
# 之剑
# 0.838970959187
# 水泥
# 街区
# 立刻
# 浅谈
# 取消
# 平民
# 哈德
# 违规
# 专门
# 黄金价格
# 仅
# 体育课
# 钢铁
# 事故
# TV
# 孔子
# 即将
# 堵
# 值得
# 炒粉
# AD
# 召开
# T2
# 详解
# 皇后
# 死
# 0.552188932896
# 吉林省
# 饮料
# 南京
# 甲士
# G20
# 外
# 一则
# 灵异
# 建行
# 萨
# 财经
# 泥头车
# 比较
# 开放
# 未成年
# 纳入
# 主城区
# 深受
# 呈
# 3712.9
# 0.745825171471
# 当年
# 大小
# 政保贷
# 不足
# 筛选
# 态度
# 看看
# 0.528611660004
# 腊红庙
# 公司
# 血糖
# 军
# 分公司
# 化身
# 皇子
# 0.86238348484
# 通杀
# 0.305097669363
# 首
# 生态
# 0.215235811658
# 柳州市
# ;
# 大法官
# 0.857833862305
# 虚假
# 黄
# 三星
# 日报
# 三诺
# 自行车赛
# 0.940928637981
# 周后
# IndiGO
# 摊点
# 度假区
# 账
# 具体
# 警方
# 天猫
# 高
# 声音
# 来不及
# 同名
# 第
# 能力
# 加盟
# 出席
# 妻儿
# 拟以
# 会议
# 以
# 当归
# 呈现
# 0.281358629465
# 显著
# 莅临
# 昌九
# 愉悦
# 自
# 安保
# 自动
# 漩涡
# 三板
# 瓷娃娃
# 上学
# 开播
# 新东方
# 撞
# 大多数
# 详情
# 0.387379795313
# 择天记
# 0.89156717062
# 0.668918088078
# 偷走
# 一句
# 一只
# 酒泉市
# 眼睛
# 喜帝
# 0.930800259113
# 国际贸易
# 医师
# 真正
# 萨德
# 专项
# 逝世
# 多仓
# 喝咖啡
# 不过
# 舒城县
# 开机
# 游
# 0.890686154366
# 纽约时报
# 长寿
# 0.750024318695
# 辱骂
# 0.349341332912
# 多云
# 优质
# 第一部
# 欧盟
# 最佳
# 多人
# 奇侠传
# 内地
# 亚洲
# 秒钟
# 捕鱼
# 多久
# 700
# 消失
# ９
# 政协委员
# 次
# 联赛
# CEO
# ChinaBio
# 一生
# 中国队
# 圣药
# 歌谣
# 0.897652924061
# 摔
# 级新生
# 官渡
# 漂浮物
# 可能
# 深入
# IPv6
# 锁
# 爆
# 集团军
# 下载
# 地
# 三时
# 贫困
# 中共
# 出境游
# 生气
# 九州
# 目标
# 继侧
# 帅气
# R
# 0.12042684597
# 未婚
# 承保
# 收益率
# 洙
# 早餐
# A股
# 早上
# 偷近
# 0.778152763844
# 教育部
# 一再
# 受损
# 应用
# 隔离
# 自拍
# 政策
# 赌博
# 颇具
# 建议
# 怪物
# 从
# 建设
# 英魂
# 纯洁
# 套
# 大神
# 十八
# 打法
# WOW7
# 水果
# ＂
# 大纲
# 大约
# 郭炳颜
# 背影
# 53
# 李大霄
# 不见
# 上方
# 高晓松
# 天下第一
# 11708
# 日晚
# 之夜
# 局
# 商品房
# 回答
# BOSS
# 120
# 122
# 端
# 罚
# 流量
# 必须
# 瞎子
# 债券
# 接受
# |
# 江苏
# 昆明
# 非常
# 深圳
# 依然
# 诉讼
# 管理
# 后市
# 唱
# 质量
# 山岭
# 一案
# 及
# 无数
# 军舰
# 避险
# 男主
# 0.514629423618
# 鉴于
# 揭露
# 私房钱
# 系统
# 全资
# 寇权
# 找
# e
# 岁
# 类食品
# 节后
# 出去
# 以正视听
# 玩家
# 逃票
# 退货
# 0.783845365047
# 大闸蟹
# 钱
# 具备
# 李希率
# 一场
# 赚钱
# 侠客
# 日本
# Alejandra
# 林志玲
# 先
# 绿色
# 幸福
# 再创新高
# 督查组
# 通报
# 值
# 修改
# 日期
# 街头
# 生日
# 金牌
# 友谊赛
# 韩国
# 病例
# 选
# 组织
# 秋天
# 时间
# 走野
# 拉开帷幕
# 重要
# 慎重
# 提高
# 宣传部
# PPP
# 十年
# 学兵
# 救助
# 农民
# 一城
# 大决战
# 之声
# 朱辛庄
# 距离
# 张梓
# 47
# 0.827818393707
# 0.855586886406
# 石头城
# 一同
# 一名
# 施工
# —
# 阿姨
# 来说
# 队内
# 多
# 招
# 兰州市
# 钱太多
# 临沂市
# 针
# 弹幕
# 长征
# 孵化
# 传送
# 信息
# 妹子
# 肿瘤
# 风暴
# 冒险
# 银政
# 关爱
# 一周
# 平时
# B5
# 辽宁
# 这种
# 之所以
# 玩法
# 下
# 颁发
# 变化
# 张奥凯
# 涨停
# 耐力
# 太湖
# 弗利
# 万人次
# ROX
# 礼仪
# 会谈
# 森美
# 0.31239002943
# 0.620921139916
# 打
# 准备
# 瓜
# 病患
# 时隔
# 23.0
# 心脏病
# 见闻
# 翠神
# 独立
# 当天
# 北非
# 脑部
# 引进
# 苗寨
# 亿美元
# 王座
# 饰演
# 发改委
# 营养
# 桥
# 变执证
# 猛烈
# 箱子
# 小伙伴
# 回声
# 武胜县
# 营养不良
# 迷影兽
# 监管
# 能否
# 食药监
# 院区
# 邮件门
# 恢复健康
# 交通事故
# 居然
# 上映
# 拓宽
# 秋季
# 粉碎
# 耳机
# 吊顶
# 加速
# 劳动
# 税单
# 康师傅
# 确保
# 0.827678442001
# 魔法
# 什么样
# 般
# 六个
# 场
# 研究院
# 0.449077213804
# 别墅
# 游泳
# 关系
# 申东烨
# 调查报告
# 出租汽车
# 副总裁
# 》
# 中介
# 执勤
# ５
# 两种
# 称其
# 消防
# 成功
# 是
# 创一流
# 富裕
# 情况
# 贬值
# 改动
# 空白点
# 0.402921814058
# 半年
# 宋智孝
# 108
# 录
# 103
# 100
# 添
# 104
# 105
# 斗鱼
# 收集
# 详细
# 0.808485865593
# 上午
# 不甘
# 消除
# 难招
# 0.306089609861
# 安陵
# 中文版
# 莱斯特
# 窑湾
# 联盟
# 上升
# 标签
# 团伙
# 账户
# 6800
# 初中
# V
# 身败名裂
# 以下
# 以上
# 加工
# 池昌旭
# 349
# 主要
# 指责
# 美国政府
# 欢喜
# 全县
# 0.27373932302
# 0.913547277451
# 晒出
# 0.908457815647
# 本期
# 想要
# 0.187148490921
# 片段
# quot
# 达成
# 配合
# 留学
# 改变
# 过半数
# 0.590696283513
# Ironman
# 盛景
# 比德
# 前
# 新品
# 烟草专卖局
# 简单
# 第九次
# 战略思想
# 数千万
# 0.835405230522
# 倌
# 成果
# 陆奇
# 10.0
# 完善
# 黑且
# 先导
# ,
# 模式
# 获赞
# 0.876738250256
# 演艺
# 重
# 市委
# 公众
# 酒类
# 前期
# 被迫
# 0.833734333515
# 水渠
# 杨幂
# 持
# 女星
# 发布会
# 流程
# 每次
# 笑
# 因为
# 新型
# 环比
# 和谐
# 幸运
# 湖南省
# 搭建
# 雷切
# 怎样才能
# 奖提名
# 分居
# 来看
# 郝培亮
# 脑洞
# 乳
# 偷
# 刮起
# 王
# 0.215362670831
# 日元
# 密集
# 0.834848046303
# 财政部
# 巧克力
# 帅哥
# 第二天
# 0.450461357832
# 遭到
# 通讯员
# 第二课堂
# 任意球
# 到位
# 皆知
# 航空学院
# 配图
# 占
# 志愿者
# 机遇
# 旨在
# 巴菲特
# 0.510815560818
# 从省
# 引
# 代码
# 找多大
# 烂尾楼
# 0.840563952923
# 厦门
# 畅通
# 圣
# 大
# ６
# 冠位
# 李开复
# 0.934622347355
# 成微信
# 0.550669003278
# 李冰冰
# 梁庆
# 姐姐
# 规范
# 展
# 冲击
# 板桥
# 历经
# 深圳市
# 公交
# 调控
# 0.742177081108
# 之镇魂
# 固定
# 无往不利
# 显示
# 万美元
# 变叶木
# 那
# 支部
# 热议
# 点评
# 当事人
# 段
# 0.271128296852
# 区
# 同增
# 落水
# 受压
# 客户
# 提振
# 摆脱
# 拥有
# 新兴
# 彰显
# 停驻
# 语言
# 海警
# 助购
# 重点
# 00
# 帧
# 三驾
# 住宅
# 快讯
# 直播
# 女性
# 基金
# 口袋妖怪
# C
# 全国
# 发出
# 担保
# 黄志荣
# 十几名
# 都
# 市盈率
# 114
# 房地产
# 途中
# 供需
# 对线
# 0.316344380379
# 两米
# 油价
# 墩
# 罗永浩
# 赛季
# 订单
# 最终幻想
# 点
# 英斯
# 调整
# 青海省
# 搞定
# 演讲
# 常春藤
# 执纪
# 0.308743774891
# 猎灵师
# CS
# 应该
# 史上
# 拍露
# 合影
# 改编权
# 交往
# 初步
# 穆里尼奥
# ℃
# 综合楼
# 宝典
# in
# 无厘头
# 常备
# 0.881974518299
# 震荡
# 白蚁
# 悲伤
# 中级车
# 架空
# VR
# 受刑
# 犀牛
# 远
# 不错
# 担任
# 受到
# 产量
# 0.346337944269
# 成城
# 龙肉
# 超低
# 手术
# 同
# 手机
# 联合国
# 结果
# 新区
# 郝蕾
# 0.772187709808
# 订做
# 叙利亚
# 诉
# Activewear
# 像
# 大唐
# 红包
# Art
# 成员
# 惊现
# 龙之谷
# 刑事
# １
# 商品
# 使用
# 军事
# 0.884394407272
# 戏称
# 虎头
# 0.922364771366
# 战争
# 程度
# 午夜
# 完全
# 地位
# 俱乐部
# 装修
# 结束
# 吃饭
# 0.406254291534
# 本周
# 产生
# 打野
# 0.371964037418
# 因涉
# 纪录片
# 女排
# 交工
# 克利夫兰
# down
# 熬夜
# 打造
# 抽取
# 英语六级
# 碧江区
# 足
# 赞成
# 地产
# NBA
# 表态
# 数据
# 视频
# DNF
# 和解
# 比例
# 吉林
# 黑
# 解决
# 着力
# Z
# 夏露
# 网路
# 蔷薇
# 黑名单
# 客运量
# 低多
# 讲好
# API
# 互联互通
# 了
# 延续
# 地上
# 地下
# 部队
# 劫杀
# 约
# 地为
# 调查
# 建设项目
# 男
# 0.849921703339
# 0.800406575203
# 三餐
# 十万元
# 作风
# 经济
# 古镇
# 改善
# 互联网
# 数控
# 表情
# Shelby
# 缩水
# 0.277121424675
# 海阳
# 搜救
# 表演
# 0
# 下半年
# 强
# 可爱
# 务实
# 0.494758546352
# 决战
# 降雪
# 医疗
# 度假
# 0.59205365181
# 文理学院
# 周
# 0.867288351059
# 身材
# 返程
# 基
# 老人
# 罕见
# 合力
# 纺织
# 办公室
# 心态
# 0.560821607709
# 旁观
# 0.880183637142
# 人有
# 河南省
# 港
# 等
# 0.842518687248
# 老干部
# 所幸
# 中签号
# 金融
# 演说
# 特惠
# 工信委
# 粘土
# 0.92829054594
# 声明
# 捡
# 统一
# boy
# 有鬼
# 0.825723528862
# 洽谈
# 过来
# 第一批
# 推出
# 海报
# 胡杨
# 初期
# 第四十二
# 0.271947950125
# 价格
# 0.896961927414
# 南京站
# 创新
# 用
# 滴滴
# 工作人员
# 陈妍
# 杯盖
# 董事长
# 贵州铝厂
# 发展
# 喜钱
# 大话
# 董璇
# 罗琳
# 红尘
# 就是
# 爱因斯坦
# 影响力
# 执导
# 哔哩
# 入耳式
# 引领者
# 喜欢
# 广西
# 147
# 142
# 蝌蚪
# 0.775168120861
# 电源
# 自称为
# 替代
# 京杭大运河
# 商家
# 老伯
# 四个
# 晶石
# 0.768087625504
# 登记
# 综述
# 布局
# 阳澄湖
# 城际
# nbsp
# 西侧
# 0.218015626073
# 0.527785003185
# 0.279893615594
# 绝杀
# 原地
# 舰
# 董子
# 旅行
# 落户
# 尾气
# 0.398413926363
# 推动
# 永泰
# 6600
# 14.0
# OPEC
# 0.458334356546
# 造成
# 男朋友
# 梦想
# 生活报
# 有
# 任务
# 义务教育
# 手段
# 进行
# 动作
# 建立
# 补血
# 警队
# 金宇彬
# 0.241779714823
# 湘西
# 贫困家庭
# 昆明市
# 人数
# 胜
# 大街
# 重组
# 曹爱卫
# App
# 单位
# 中小企业
# 二审
# 驴友
# 0.264427363873
# 已久
# 毒角兽
# 执教
# 前妻
# PVP
# 古言
# 吉娃娃
# 发布
# 娶
# 0.760812699795
# 建筑
# 动人
# 行动
# 11
# 10
# 13
# 12
# 15
# 14
# 17
# 16
# 19
# 18
# 精神病
# 路
# 0.54354562637
# 立法
# 0.913901746273
# 损失费
# 中药饮片
# 尽全力
# 一代
# 砍
# 欧元
# 家长
# 参赛
# 金融业
# 成都市
# 难
# 200
# 剑
# 图书馆
# 煤炭行业
# 刚刚
# 0.548059943318
# 0.906254291534
# 还
# 女友
# 整治
# 国家图书馆
# 新建
# 哪
# 最萌女
# 原因
# 贯彻落实
# 0.522795319557
# 显然
# 两
# 球员
# 赛前
# 患有
# 井柏然
# 讲故事
# 2529
# 全市
# 恭王府
# 利润
# 城管
# 每日
# 东河区
# 任命
# 拟
# Munda
# 受审
# 领衔主演
# 上门
# 脑震荡
# 比分
# 制作
# 本市
# 家用
# 二次元
# 半城
# 廊坊
# 满瓶
# 抬车
# 借贷
# 京
# 硬件
# 分别
# 市场
# 商店
# 道
# 单
# 经费
# 穿恨
# 拉力赛
# 魔性
# 重磅
# 尚未
# 部
# 交警部门
# 东西
# 集团股份
# 房价
# 开通
# 企稳
# 前往
# 介于
# 顾问
# 不良
# 金色
# 0.867706775665
# 哈医大一院
# 内蒙古
# 赛区
# 买房
# 便民
# 至
# 两份
# 举行
# 祸
# 参访
# 国
# 评估
# 执念
# 克苏
# 0.235374391079
# 新增
# 月底
# 民警
# 创意
# 夜间
# 抽奖
# 现状
# 17.0
# 野秀明
# 死亡率
# 巡检
# 开出
# 先后
# 人才
# 公安局
# 哦
# 全身
# 酒店设计
# 了解
# 项
# 一
# 成就
# 小青年
# 合同
# 共有
# 蓝光
# 搜
# 化解
# 然后
# 示范
# 4
# 药方
# 林采欣
# 致
# 之大
# 德州人
# 从今年起
# 法新社
# 朴经
# 在京举行
# 硕士
# 承认
# 小伙
# 对
# 马刺
# 风险
# 穿戴
# 办法
# 专注
# 0.959509968758
# AG
# 吧
# 复牌
# 环城
# 国企
# 持有
# 生命科学
# 盐
# 冻产
# 支持
# 一事无成
# 何鸿燊楼
# 李昊城
# 大豆
# 兴趣
# 0.802345951398
# 原创
# 0.570318490267
# 文
# 冷空气
#
#
# 福
# 提档
# 实行
# 美爆
# 手游
# MacBook
# 比亚迪
# 中国足协
# 小久
# 预计
# 提案
# 装
# 注册
# 0.53830906323
# 香菇
# 0.817758560181
# 六中全会
# 法院
# 拉肚子
# 骨折
# 原副
# 图片
# 撞伤
# 时期
# 爱
# 栅
# 水平
# 万桶
# 路段
# 考察
# 俊杰
# 67.10
# 全总
# 0.229518967991
# 凉皮
# 吴谦
# 忙碌
# 0.249011687934
# 庆祝
# 他
# 橙
# OnFire
# 小萝莉
# 巡回演唱
# 电脑
# 大赛
# 人民代表大会常务委员会
# 无限
# 职业
# 装备
# 通过
# 凌晨
# 房产
# 且
# 华尔街
# 夜行
# 116.0
# 宝
# 汇顶
# 转正
# 主食
# 国内
# 霍勒迪
# 0.950598537922
# 分享
# FIGURE
# 不断
# 面积
# 狗
# 开赛
# 签约
# 每种
# 差别
# 无视
# 0.829350233078
# 主题
# 决斗
# 关注
# 众泰
# 任性
# 不料
# 对比
# 李广
# 高分
# 再下
# Giants
# 战士
# neoen
# 0.949997484684
# 数
# 通车
# 个人信息
# 争霸赛
# 下发
# 5000
# 0.545106172562
# 巨齿
# K
# 龙山县
# 赛事
# 繁华
# 天高
# 来
# 北部湾
# 脂肪酸
# 控制
# 适当
# 0.503602802753
# 0.901495456696
# 未知
# 问答
# 实际
# 旧金山
# 春夏
# 0.430675894022
# 低位
# 爆炸
# 灌区
# 0.83
# 古巨基
# 致日
# 金融服务
# 现已
# 0.809459686279
# 精致
# 仔卓伟
# 影片
# 鸟蛇
# FMG
# 抵达
# 0.889289855957
# 崔岷植
# 我要
# 意外
# 单品
# 女生
# 中心
# 红血丝
# 疯狂
# 国债
# 北
# 首映礼
# 海口
# 电信业务
# 封杀令
# 致敬
# 三转
# 三市
# 局长
# 重度
# 央广网
# 普通
# 复活
# 0.421156078577
# 好友
# 各
# 奶僧
# 台州
# Note
# 江汉
# 19.8
# 0.87587594986
# 24
# 25
# 逐渐
# 27
# 21
# 22
# 23
# 离婚
# 28
# 投诉
# 公开
# 精英
# 发微博
# 两款
# 上诉
# 0.581958857179
# 大部
# 莱纳
# 无证
# 开车
# 白酒
# 将建
# 问政
# 相撞
# 建成
# 违法
# 电影节
# 八名
# 马
# 0.914036095142
# 中化
# 高位
# I
# 皇室
# 大选
# 达
# 0.140800721478
# 终
# 欢天
# 马云
# EP
# 大道
# 代表性
# 万达
# 走红
# 老红军
# 0.621803919474
# 购物
# 0.658442653716
# 专项资金
# 潜水
# 升至
# 气候
# 十分
# 银行
# 钠盐
# 福州
# 0.582812011242
# 评论员
# 得到
# 公布
# 职务
# 恒大
# 炫舞
# 透明
# 46980
# 发飙
# 党建
# 酒窝
# 大量
# 楼
# 展示
# Esprit
# 紧紧
# 阳光
# 告诉
# 如果
# 白云路
# 局面
# 探索
# 沪
# 贯彻
# 路边
# 0.878082573414
# 不是
# 忽略
# 规定
# 阵型
# 人类
# Win10
# 申崇
# 遭
# 收藏
# 身份证
# 火灾
# 为什么
# 气场
# 逃离现场
# 写
# 合一
# 局部
# 引擎
# 骚扰电话
# 百度
# 0.134247115627
# 8
# 聚众赌博
# 大雾
# 跑
# 确定
# 盗
# 党委
# 感情
# 竟
# 公安机关
# 期盼
# 资产
# 感想
# 再起
# 0.954750955105
# 表现
# 留学生
# 0.679579174519
# 港股
# 研讨
# 传出
# 长效机制
# 蔡
# 片
# 发动机
# 不慎
# 发行价
# 赴
# 产能
# 担心
# 0.854722380638
# 积极性
# 进阶
# 0.285098727793
# 海龙
# 副
# 大陆
# 举重
# 时
# 外贸
# 单元
# 金福珠
# 骗
# 通苏嘉
# 不想
# 0.411338716745
# 中学
# 三
# 走进
# 源源不断
# 合作
# 开行
# 车道
# 金马
# 0.936202824116
# DPtech
# 园
# 0.422882188267
# 设立
# 老去
# 拼命
# 互
# 信用
# 恋人
# 德国
# 过程
# 高空
# 中考
# Jenson
# 疑心
# 0.914584994316
# 角卫
# 养老金
# 艺术
# 报告会
# 0.87
# 非法
# 铺设
# 比
# 0.700740791857
# 孤峰
# 双方
# 努力
# 流浪
# 变大
# 女
# 猪圈
# 亿股
# 0.693504393101
# 视角
# 快餐
# 英皇
# 红色旅游
# 视觉
# 级别
# 田朴珺以
# 原则性
# 推介
# 近
# 人称
# 办理
# 林志颖
# 车
# 上述
# 升学
# 强赛
# 别人
# 之下
# 这里
# 播求
# KO
# 自救
# 公寓
# 吗
# 租赁
# 资源优势
# 广阔
# 可治
# 国网
# 开设
# 辆车
# 300
# 大部地区
# O
# 里
# 重拳
# 坐在
# 条
# 文化部
# 0.457579344511
# 增加
# 0.561934947968
# 地摊货
# 业内人士
# 排放
# 导读
# 证明
# 女王
# 空头
# 乳粉
# 中奖
# 投入
# 日起
# 导语
# 持续
# 抓取
# 传前
# 1.50
# 贼
# 巨型
# CF10
# 0.331763595343
# 专电
# 危机
# 专用
# 逐步
# 羚山
# 任何
# 中央
# 哭
# 选手
# 离开
# 蛇口
# 红黑榜
# 涉嫌
# 单刷
# 地市
# 意念
# 这部
# %
# 此事
# 服装界
# 优惠
# 洞窟
# 金额
# 正视
# 大错
# 老兵
# 白银
# 刚下
# 旗下
# 海南岛
# 0.181767576064
# 进一步
# 查获
# 行为
# 游戏
# 均价
# 制品
# 约定
# 2000
# 0.920368611813
# 行业
# 去年
# 刘扬来
# 电网
# ↑
# 黄金市场
# 麻豆
# 0.784285604954
# 转换
# 渤
# 美媒
# 暴露
# 生育
# 0.762935519218
# 奖励
# 巴士
# 一下
# 江西网
# 敲诈勒索
# 鄂尔多斯市
# 盗墓
# 入口
# 带动
# 统战部
# 电缆
# 调研
# 身体
# 包邮
# 工程
# 领空
# 北部
# 行凶
# ２
# 异能
# 森福罗
# 宠物
# 迎来
# 特点
# 设计
# 免费
# 3D
# 方案
# 国外
# 进驻
# 房子
# 0.329066649079
# 0.81275254488
# 中国
# 制定
# 利率
# 图文
# 钢管
# 442
# 救命
# 草案
# 发文
# 38
# 一两
# 微软
# 31
# 30
# 36
# 35
# 督办
# 小妙
# 器重
# 弄
# 率
# 0.742101728916
# 窝点
# 公告
# 展现
# 几百万
# 集团化
# 副局长
# 年轻
# …
# 新鲜事
# 照片
# 定西
# 城乡
# 为
# 抽
# 六场
# 麦田
# 环保
# 0.139146819711
# 产品线
# 天空
# 0.127947792411
# 0.715700685978
# 道路交通
# 0.417147691051
# 请
# 新能源
# 糕点
# 枪击
# YG
# 东方
# 编剧
# 换届选举
# 对战
# 典型
# 电气化
# 八强
# 炒房团
# 0.569031587243
# 秀
# 登顶
# 道士
# 美国联邦
# 党员
# 金智秀
# 那英
# 0.794100522995
# 僵尸
# 市长
# 药物
# 更是
# 暴雨
# 概念车
# 国家
# 小学
# 四川
# 谢台
# 下跌
# 原则
# 国宝
# 撒漏
# 克洛普
# 12.05
# 前不久
# 新作
# 规则
# 国人
# 规划
# 非
# 网票制
# 技巧
# 第五次
# 更新
# IT
# 打赌
# 卧式
# 0.464854886755
# 如
# 梅拉
# 创
# 地区
# 人生
# 指挥部
# 总局
# 上岗
# 力量
# 倒卖
# 击毙
# 航企
# 宋茜
# 字
# 肾积水
# 圈
# 残
# 收购
# 涌
# 拦截
# 辣
# 禁入
# 退欧
# 0.923282146454
# 0.400816887617
# 帮
# 碾压
# 一事
# 客户端
# 心
# 几天
# 读者
# 音乐
# 青春
# 上调
# 诉求
# 增强
# 以后
# 理念
# 0.403083860874
# 如潮
# 找寻
# 却是
# 好奇
# 竭尽所能
# 首发式
# 讲解
# 搜狐
# 于
# 我
# 贝克汉姆
# 0.155380721204
# 互动
# 互助
# 日至
# 0.302546769381
# 消费
# 0.872253298759
# 复杂
# 公园
# 翼博
# 减少
# 第十位
# 0.271658301353
# 居
# 摄入量
# 提
# 棚户区
# 回
# 风范
# 发红包
# 职工
# 0.896245419979
# 成为
# 流通业
# 古巴
# 装饰画
# 可是
# 传奇
# 斗蟋蟀
# 0.502850635598
# 公共
# 方法
# 巴比伦
# 丁二烯
# 慈善
# 四家
# 家族
# 有钱
# 站稳
# 离合
# 天际
# 0.831951618195
# 老婆
# 纪念
# 闪现
# 心理
# 世界级
# 疑因
# 两旺
# 成交
# 湖北
# 缓解
# 以及
# 0.846667766571
# 更换
# 房
# 0.314413070679
# 格林
# 位置
# 位
# 东兴
# S
# 材质
# 大跌
# 黄颂平
# 大鹏
# TFBOYS
# 示范区
# 开考
# 导致
# 中华
# 鲜明
# 墙
# 以前
# 全优
# 大学生
# 保时捷
# 门窗
# Brooklyn
# 欺负
# 拿下
# 画像
# 相比
# 台办
# 妹妹
# 晒
# 显示器
# 短信
# 农田
# 全体
# 海盗
# 嘉峪关市
# 0.695830213527
# 制度
# 高开
# 男儿本色
# 中叙
# 万能
# 满族
# 第十一次
# 台剧
# 怎么办
# 散煤
# 泡澡
# 啊
# 人物
# 劝酒
# 坦帕
# 实验
# 终极
# 日本女排
# 月份
# 恩
# 宴请
# 木制品
# 六号
# 利益
# 到来
# 马拉松赛
# 一份
# 虽
# 表示
# 黄金时代
# 10.25
# 攀
# 10.28
# 对方
# 利用
# 死亡
# 七号
# 尤其
# 二人
# 两证
# 以免
# 心机
# 培养
# 加里
# 西安
# 换成
# 西宁
# 二代
# 钢索
# 提示
# 双港
# 万茜
# 购众
# 红火
# 0.639616571367
# 赢
# 阿房宫
# 赵丽颖
# 枸杞
# 有趣
# 仍存
# 新西兰
# ！
# 林
# 对此
# 黏剂
# 城楼
# 悬疑
# 景德镇
# 0.248690545559
# 0.369173198938
# 经理
# 形式
# 小心
# 样品
# 前瞻
# 北京大学
# 肯尼亚
# 美国大学
# 地块
# 上限
# 地址
# 信访
# 单孔
# 四大
# 嫌疑人
# 0.528467598557
# 开
# 处
# 猎人
# 家暴
# 补贴
# 快通
# 衣橱
# 快速
# 额度
# 小幅
# 0.923142671585
# 国庆
# 乐视
# 购买
# 速度
# 0.229251174132
# 却成
# Dee
# 如此
# 你
# 回顾
# 地图
# 1180
# 预警
# 魔王
# 几招
# 战地
# 守望
# 0.334420144558
# 积极
# 查询
# 旅客
# 致歉
# 网
# 八大
# 新华社
# 抗议
# 43
# 40
# 第十四届
# 房屋
# 生态环境
# Phase
# 他人
# 镇
# 某
# 4K
# 发展前景
# 4G
# 好莱坞
# 净利润
# 春城
# 阵容
# 收视
# 称为
# 是否
# 鸡蛋
# 老太
# 他们
# 传媒
# 即
# 阐释
# 书记
# 失联
# 河南
# 青海
# 改版
# 案件
# 发生
# 放入
# 瓶子
# 欲
# 沉睡
# 安全隐患
# 34D
# 河北
# GO
# 针对
# 中渡
# 揭
# 接连
# 蓬溪县
# 京西
# 接近
# 李白
# 新疆
# 苏丹
# 谎言
# 鲨
# 技术
# 邓绥
# 货币
# 欢瑞
# 城在
# 遗失
# 身为
# 失灵
# 食堂
# 扶持
# 秦
# 往年
# 人体
# 会及
# 下调
# 帮堂
# 增效
# 晒照
# 国防部
# 人事
# 参观
# 徽铁
# 卡萨尔
# 新动向
# 人们
# 0.459235548973
# 就业
# 案例
# 考生
# 半程
# 剑士
# 少
# 多个
# 0.551287348072
# 倍
# 自身
# 补助
# 长子
# 清晨
# 惊醒
# 台湾
# 流失
# 麻雀
# 老板
# 艺卓
# 10.7
# 道具
# 双
# 0.859392821789
# 纪检监察
# 与其
# 陈乔恩
# 王者
# 不同
# 杯
# 一说
# 退出
# 工作室
# 账号
# 两学
# 精神损失
# 韩书力
# 员
# 皮肤
# 首饰
# 1370
# 404
# 16.0
# SAT
# 一行
# 超限
# 挤爆
# 0.845313847065
# 规模
# 怒
# 原罪
# 奥林匹克
# 几张
# 指标
# 创业
# 第一位
# 瞎
# t1
# 冢
# 妖姬
# 违法行为
# 中泰
# 送命
# 故
# 村民
# 0.96244686842
# W
# 两家
# 攻坚战
# 采暖
# 电子竞技
# 卡
# 花费
# 0.503419995308
# 疾病
# 据悉
# 青年
# 哪儿
# 贩卖
# 荷花
# Silpada
# 原是
# 建华
# 双十
# 烟叶
# 引发
# 中海
# 证券
# 0.792287349701
# 升温
# 富德
# 0.725470721722
# 0.45511918515
# 0.881607651711
# 烦恼
# 可奖
# 0.197345325723
# 煤气
# 与友
# 超模
# 0.57990449667
# 18.0
# 酒后
# 五
# 单卡
# 全年
# 国际化
# 客运码头
# 费用
# 景气
# 双双
# -
# 冯波
# 绘画
# 形成
# 舒适
# 节前
# Omega
# 说
# 0.435200214386
# 一览
# 华龙网
# 无与伦比
# 学车
# 个别
# 企业
# 0.48579248786
# 竟然
# 停车场
# 混血儿
# 联合
# 老年
# 军民
# 到底
# 以此
# 咋
# 小散
# 留给
# 拥堵
# 验钞机
# 东
# 注销
# 防水
# 代表团
# 实施方案
# 蓝筹
# 制服
# 联发
# 许多
# 梗后
# 嘻哈
# 门萨
# 健康
# 地下城
# 问世
# 惊人
# 军训
# 不再
# 一入
# 深
# 车队
# 来源
# 现实
# 斥责
# eBay
# 调研组
# 遭疑
# 小时
# 0.910497665405
# 一身
# 减持
# 369
# 恶气
# 362
# 360
# 酒友
# 0.891438364983
# 最重
# 城区
# 检验
# 油漆
# 送到
# 方向
# 类
# 穿
# 缺席
# 刚才
# 必将
# 升格
# 牛顿
# 内衣
# 青涩
# 全省
# 0.928073585033
# 防洪
# 中国籍
# 四折
# 0.5123437047
# 部门
# 魔
# 伪装
# 挖出
# 金志
# 短短
# 一轮
# 暂
# 一辆
# 0.676827982068
# 海中
# 美国司法部
# 缭绕
# 预选赛
# ’
# 众多
# 赌资
# 重达
# 老照片
# 斯坦森
# 自行车
# 不停
# 陆续
# 首段
# 洛桑
# 部长
# 0.405017028004
# 画面
# 赛
# 换血
# 优势
# 优先
# 民办教育
# 石化
# 青蛙
# 带泪
# 熊黛林
# 附近
# 湟平
# 全球
# IOC
# 增至
# 管理中心
# 中标
# D
# 但
# 0.852305293083
# 帐号
# 接触
# 59
# 被行
# 白沙洲
# 恶搞
# 55
# =
# 荣耀
# 50
# 买
# 0.745500564575
# 戏外
# 多次
# 江映蓉
# 落下
# 发现
# 时代
# 透
# 纺织工业
# 报名
# 今起
# 抓手
# 试验
# 北方地区
# 大厨
# 会同
# 会后
# 扑
# 命运
# 报告
# 鹿晗
# 颜值
# 增长
# 出
# 李小璐
# 写作
# 娱乐
# 型
# 家庭
# ０
# 怎么样
# 0.492015838623
# 失守
# 进口
# 下午
# 冬天
# 车辆
# 跨境
# 缺少
# 赛车
# 许婧
# 齐
# 新片
# 增持
# 新版
# GMP
# ColorEdge
# 0.897459924221
# 悉尼
# 两市
# 瑞士
# 一起
# 候选人
# 驾
# 律师
# 每个
# 黑天鹅
# 名
# 面临
# Pop
# 相关
# 古琴
# 养生
# 避免
# 阿Q
# 面世
# 本田
# 维和
# 方块
# 因此
# 不利
# 认为
# 不到
# 授权
# 来到
# 入选
# 伯恩茅
# 澳大利亚
# 一路
# 领海
# 秩序
# 美食
# 原生
# 出轨
# 以来
# 罐车
# 整体
# 绝密
# 低估
# 名义
# 渐渐
# 号码
# 现场
# 吨
# 被
# 艺术宫
# 一般
# 全程
# 艺术家
# 现在
# 保险
# 0.559826023877
# 行政处罚
# 斯菲尔德
# 对口
# 转化
# 卒
# 客串
# 扬尘
# 主播
# 控股
# 主持人
# 灵车
# 协议
# 奔驰
# 0.843377709389
# 勇者
# 星
# 停车
# 整修
# 党政
# SERIA
# 0.390182167292
# 保障
# 侧翻
# 广州市
# 提供
# 吸附
# 洛杉矶
# 穷
# 成立
# 二婚
# 24.0
# 本溪
# 之谷
# 0.388078927994
# 砍盾
# 婚讯
# 明年
# WCBA
# 寻人
# 按揭
# 签署
# 之谜
# 需求
# 金融中心
# 跨国
# 大众汽车公司
# 中有
# 满月
# 报导
# 山西
# 整个
# 崩坏
# 前男友
# 巴楚
# 适合
# 期
# 相通
# 电价
# 1
# 相当
# 拉客
# 库存
# 半
# 俄
# 富
# 号称
# 运动
# 西江
# 酒店
# 英雄传
# 贫困户
# 城市
# 优化
# 不少
# 西北地区
# 思路
# 建
# 存下
# 分拆
# 最
# 堪称
# 惊心
# 管
# 女人
# 室友
# 高品质
# 澄迈
# 大儿子
# 新技能
# 朱元璋
# 林心如
# 再见
# 这
# 26.7
# 26.0
# 印刷
# 可信度
# 0.611992751559
# 逼近
# 韩
# 持有人
# 上交所
# 头部
# 来得
# 教育
# 两只
# 黄觉
# 重庆
# 经济合作组织
# 高校
# 归还
# 白银区
# 华裔
# 0.71077311039
# 体系
# 配置
# 清洁
# 组委会
# 街
# 由于
# 理肤泉
# 员工
# 购物中心
# 拿
# 评分
# 月
# 妈妈
# 在
# 0.37042850256
# 宝贝
# 长白山
# 女侠
# 严重
# 0.767459988594
# 0.913358569145
# 0.914820432663
# 本科
# 28.0
# 川式
# 28.5
# 引客
# Love
# 电路板
# 名额
# 公交车
# 健全
# 纪念日
# 搏杀
# 炒
# ”
# 不幸
# 研究进展
# 中日
# 帮助
# 一系列
# 首部
# 防控
# 首都
# 失误
# 济南
# 中文
# 间隔期
# 找到
# 玩起
# 县级
# 橙卡
# 信息量
# 何穗
# 0.783346176147
# 城将
# 门锁
# 使
# 敦煌
# 图
# 趁
# 党委书记
# 食品
# 卡里克
# 环保部
# 简约
# 使得
# 地方
# 高中生
# 鲸吞
# 0.868014037609
# 多人多
# 劳动报
# 秋裤
# 0.146873801947
# 征途
# 斗玩网
# 考研
# 专业
# 隧道
# 疯传
# 首露
# 工业
# 屏幕
# 专一
# 诺必行
# 高清
# 不好
# JADE6
# 中招
# 产业链
# 大众汽车
# 多项
# 吻
# 排序
# 起来
# 追究
# 先生
# 京藏
# 各项
# 26
# 季报
# 不太
# 工人
# 20
# 蓝洁瑛
# 成绩
# 0.666865974665
# 多少岁
# 略有
# 彻底
# 苦痛
# 前萌样
# 容易
# 庞大
# 不多
# 故事
# 江南
# ，
# 60
# 62
# 气温
# 拉开
# 蹲坑
# 奥拉
# 位于
# 讯
# lols6
# 工作
# 席卷
# 烧毁
# 500
# 自行车道
# 有德
# 镐
# 姣
# 两名
# 融合
# 房源
# 失败
# 评级
# 子公司
# 更加
# 改编
# 韦德
# 把
# 潜力
# 督查
# 带来
# 入驻
# 检查
# 党性
# 萱
# 新
# 0.533448576927
# 解答
# 焦耳
# 男孩子
# 矿石
# 橱柜
# 风
# 0.545646727085
# 军旅
# 李
# ID
# 诺
# 高潮
# 瓦
# 婚车
# 度
# 0.03
# 窃贼
# 小区
# 西段
# 卡车
# 0.408514690585
# 阳泉
# 救护
# 歌声
# 南非
# 合理
# 余万元
# 玩
# 身
# 对善
# 马特
# 0.890010535717
# ESWC
# 汽车
# 自嘲
# 日
# 韵家口
# 共享
# 两地
# 的哥
# 失踪
# 将成
# 还有
# 0.85539329052
# 摘要
# 波动
# 雪花
# 怨恨
# 度过
# 浙江
# 众创
# 共同
# 亿人次
# 销量
# 跃居
# _
# 瑞典
# 历史
# HTC
# 三伤
# 地板
# 错峰游
# 硕
# 登
# 0.647329469522
# 肃州
# 空间
# 米其林
# 战略
# 0.679729600747
# 支援
# 出行
# 张
# 协调
# 0.493895413478
# 藤原
# 救援
# 0.782242655754
# 模特
# 吸量
# 蔡振华
# 该省
# 关口
# 退役
# 高速
# 来袭
# 航空
# 制冷
# 车间
# 4.0
# 恢复
# 5
# 输入
# 城塔
# 浙江省
# 别看
# 最高
# 方式
# 情绪
# 0.869365811348
# 女童
# 欢笑
# 论坛
# 帮困
# 关卡
# 要
# 靓丽
# 0.0226245224476
# 南美洲
# 物语
# 过往
# 8090
# 新政
# 供电系统
# 0.341866701841
# 天气预报
# 干部
# 路人
# 一面
# 锦标赛
# 富时
# 促进法
# 知名
# 预防
# 班
# 0.396308034658
# 后心
# 每天
# 很少
# 西甲
# 地铁线
# 权力
# 党代会
# 中安五艾
# 穿少
# 秦始皇
# 幕后
# 北京市
# 仙境
# 动画
# 0.899008989334
# 0.203757959884
# 仔
# 之间
# 0.862614870071
# 昔日
# 情况危急
# 祖马
# 博物馆
# 完美
# 米
# 印度
# 金融界
# 郭庄
# Top
# 特大
# 陶瓷
# 魔兽
# 演
# ET
# 造好
# 0.8874142766
# 甘肃省
# 杨洋
# 庵
# 获
# 密码锁
# 复婚
# 甚至
# 0.756512641907
# 0.84151494503
# 篇
# 受
# 客场
# 0.580475151539
# 武湖
# 二
# 或许
# 融资难
# 连赢
# 解析
# 上攻
# 0.734101593494
# 因素
# ７
# 达到
# 0.826759874821
# 第三轮
# 批评
# 验收
# 医院
# 地市级
# 集资
# 0.41536436975
# 再次
# 支付宝
# 深化
# ？
# 5.0
# 原油
# 试运营
# 平
# 颜杀
# 要说
# 曾经
# 决定
# 申购
# 领取
# 才
# 0.743555307388
# 经
# 0.615029308945
# 提起公诉
# 扳平
# 脱离
# 工厂
# 现代
# 公安厅
# PPI
# 0.534264191985
# 夕阳
# 代号
# 此次
# 关于
# 电商
# 习性
# 下来
# 合格
# 农学院
# 渠道
# ·
# 众人
# 国王
# 利好
# 林允
# L
# 工研院
# 哈市
# 大队
# 0.822975516319
# 创建
# 印尼
# 认定
# Ready
# 复习
# 接下来
# 0.397470682859
# 杀青
# 一颗
# 实践
# 形势
# 墨镜
# 别
# 海外
# 加勒比海
# 顺利
# 长春市
# 郑洛新
# 0.867157280445
# 扩大
# 比赛
# 0.468198984861
# 产业基地
# 明太祖
# 标志
# 。
# 段烛
# 0.867733359337
# 期内
# 大中华
# 存在
# "
# 0.114163534556
# 0.937226653099
# 提款权
# 0.844425797462
# 8600
# 1.1763
# 党组
# 届
# 整合
# 洋房
# 之际
# 启动
# 走强
# 热
# 成交量
# 苏州
# 购房
# 0.937490582466
# 保质
# 提名
# 赶走
# 手势
# 升级
# 照曝光
# 清理
# 75
# 解放
# 限购
# 航标
# 青云
# 史泰龙
# 落实
# 专业级
# 小到中雪
# 于是
# 0.8493039608
# 梦幻
# 截至
# XR
# 街道
# 接
# 搭档
# 0.777774751186
# 带给
# 3120
# 终止
# 污染
# 提升
# 类型
# 挺
# GeekCar
# 全景
# 门口
# 资源
# 0.963550984859
# 超紫
# 短
# 司法局
# 小生
# 新加坡
# 时尚
# 牛角
# 包
# 部落
# 中立
# 顾敦禹
# 经常
# 0.452410490614
# 2.0
# 2.4
# 马克杯
# 提取
# 剑侠情缘
# 构建
# 特岗
# 朋友圈
# 前景
# 立即
# 终于
# 扩张
# 治疗
# 可以
# 健一
# 奇迹
# 竟是
# 老爸
# 赏金
# 全民
# 中等
# 模样
# 0.899311006069
# 成本
# 秘宝
# 报
# 对于
# 五大
# 海底
# 很
# 冷门
# 中签
# 好看
# 提前
# 专场
# 提到
# 责任
# 0.853084802628
# 不得不
# 若
# 0.243601545691
# 刺杀
# 之道
# 治理
# 惹
# 很多
# 19.0
# 水晶宫
# 本月
# 瓜帅
# 短期
# 怒气
# 女儿
# 结合
# 完成
# 9
# 只能
# 电力
# 峰会
# 后面
# 领域
# 挑战赛
# 幼儿园
# 客厅
# 本来
# 城镇化
# 电动
# 0.198161184788
# 气电
# 刘有明
# 欲望
# 悬崖
# 剑侠
# 发挥
# 用药
# 西向东
# 落幕
# 两位
# 国美
# 卖身
# 新歌
# 不动产
# 0.518766999245
# 款
# 萨里
# 延伸
# 黄锐
# 田间
# 英国
# 电视剧
# 利物浦
# 鲁迅
# 提出
# 人大
# 做好
# 3.0
# X射线
# 多月
# 社交
# 华银
# 盛典
# 路过
# 公务员
# 女婿
# 阿根廷
# 建国初期
# 物资
# 设备
# 绘本
# 0.623898744583
# 0.670466572046
# 执法人员
# 车型
# 美观
# 弹
# 今年以来
# 已
# 争议
# 隔壁
# 巅峰
# 本文
# 率先
# 0.464387774467
# 游客
# 居住证
# 通
# 心得
# 社会
# 航拍
# 合规
# 毫无疑问
# 两个
# 人士
# 促进
# 讲真
# 新手
# 活动
# 本旬
# 一个多
# 成效
# 卫
# 借鉴
# 全新
# 家中
# 丑
# 动物
# 市民
# ；
# 情暖
# 亦
# 讨
# 李准
# 交流
# 听到
# 二期
# 0.521976292133
# 活到
# 嫌犯
# 白皮书
# 两人
# 0.85283011198
# 每年
# 影响
# 竞
# 挑战
# 超级
# 行李
# 实用性
# 菸
# 0.857810497284
# 0.489779680967
# 早起
# 红海
# 淘宝
# 咨询
# 检疫
# 美
# 买不起
# 捉
# 输配电
# 电影
# note7
# 南通
# 玉器
# 珠宝
# 左江治旱
# 走向
# 扶贫开发
# 谷
# P
# 不可救药
# 蓝月
# 信用风险
# 戒毒
# 上万条
# 泄愤
# 郑爽
# ?
# 新浪
# 时候
# 巡查
# 花静
# 贵阳
# 创作者
# 希拉里
# 蓝瘦
# 关键性
# 永远
# 洪水
# 你们
# 脉脉
# 面具
# 网店
# 河北省委
# 0.931140959263
# 总队
# 0.862399220467
# 27.0
# 0.826367139816
# 分析
# 汇总
# 相信
# 窥探
# 柯震东
# 行情
# 伤
# &
# 撩
# 经历
# 地点
# 片区
# 讷
# 逃避
# 几吨
# 办学
# 攀附
# 房产证
# 男孩
# 国土资源部
# 名誉
# 发生意外
# 四级
# 克烈
# 看透
# 0.0
# 0.5
# 劫持
# 调度
# 原文
# 聚餐
# 真
# 财务
# 嘟嘴
# 海关总署
# 安迪
# UI
# 皇马
# 股票代码
# 城中
# 专家
# 竞拍
# 院长
# 抓紧
# 排名
# 领导
# 陪月子
# 核查
# 酒店业
# 特别
# 如下
# 成
# 木村
# 134
# 仿生
# 射线
# 采访
# 渔船
# 0.624991794427
# 原本
# 担当
# 原木
# 回升
# 推介会
# 结对
# 砍断
# 陈
# 恩德
# 低
# 首脑
# 新一轮
# 掉落
# 李小
# Pro
# 0.406376421452
# 原来
# 熊晶
# 飞车
# 今天上午
# 榜单
# 88
# 82
# 专访
# 80
# 人工智能
# 热度
# 王俊凯
# 推手
# 0.864940583706
# 或者
# 0.605335578322
# 总计
# 如今
# 学院
# 最近
# 国有资产
# 安吉斯
# 便宜
# 另外
# 一部
# 0.444853633642
# 不会
# 派出所
# 焦雷
# 蒋介石
# 石下
# K2
# 流浪狗
# 不仅
# 男鬼
# 新游
# 尖叫
# 0.869101703167
# 环境治理
# 显
# 续集
# 顶级
# 一周年
# 如何
# 怀孕
# 叫做
# 花钱
# 不了
# 记者会
# 杨
# 晚间
# 1.4
# 1.0
# 1.2
# 二次
# 平均
# 公益
# 停车位
# 0.911443948746
# 猛
# 已经
# 生
# 金竹山
# 手游带
# 专委
# 索赔
# 现
# 东部
# 持刀
# 上火
# 起火
# 钱币
# 用风女
# 结构性
# 原班人马
# 经典
# 来临
# 结婚
# 边锋
# 恋情
# 面前
# 人员
# 间
# 休闲
# 运营
# 电子
# 超
# 自住型
# 千名
# 同类产品
# 过去
# 高级
# 宝宝
# 抽检
# 借款
# 巷
# 装甲
# 人口
# 茉莉
# 海南省
# 艺人
# THE
# 该
# 发表文章
# 盛宴
# 恨
# 考核
# 专题
# DNF2016
# 0.522544920444
# 市委书记
# 神谕
# 海在
# 福特
# 题
# 凭借
# 驮
# 国务院
# 一组
# 哪些
# 毕业生
# 坠落
# 抽样
# 西欧地区
# 脸型
# 签到
# 轿车
# 分手
# 于晓光
# 依赖
# 板块
# 火影
# 巡讲
# 交易
# 气电之星
# 诞生
# 连阴
# 必备
# 住房
# 期待
# 小米
# 没
# 踢
# 消费者
# 诈骗
# 偶像
# 美股
# 军用
# 护发
# 幂
# 寻找
# 每
# 徒步
# 志
# 车门
# 证券化
# 此
# 嘉宾
# 启用
# 介绍
# 活动区
# 却
# 担忧
# 申报
# 封杀
# 印发
# 土地证
# 不
# 谄媚
# 0.904251515865
# 一套
# 新梅
# 南昌
# 迷妹
# 0.683406144381
# 内部
# 走出
# 泰坦
# 注意
# 0.749895393848
# 俄罗斯
# 刘斌
# 每周
# 国际奥委会
# 拍卖行
# 意大利
# 资本
# 抢劫
# 刺激
# 首选
# 商业银行
# 首支
# 召集
# 事
# 0.623131245375
# 平方米
# 兰州
# 总部
# 0.4161850214
# 0.912751853466
# 新款
# the
# 暗度陈仓
# 总书记
# 浴照
# 争霸
# 金塔县
# 球星
# 美腿
# 餐饮
# 国际货币基金组织
# 演职人员
# 顺序
# 携手
# 外星人
# 小编
# 0.528630468994
# 星际争霸
# 赵灵儿
# 样样
# 胭脂
# 116
# 安装
# 0.453663021326
# 执法
# 黑龙江省
# 乘客
# 集
# 方媛
# 融化
# 群侠传
# 希自
# 跌
# 村
# 0.651822030544
# 卷轴
# 0.839438438416
# 双人
# 各自
# 表姐
# 走势
# 搞怪
# 土豪
# 它
# 传媒网
# 温格
# 例
# 《
# 退伍
# 投票
# 特地
# 看点
# 0.631976515055
# 传
# 雷曼
# 赌场
# *
# 任期
# 少见
# 总量
# 层
# 个人
# 0.846415519714
# 务求
# 资料
# 顺德
# 航空公司
# 索要
# 大巴车
# 证书
# 画风
# 0.620447819432
# 号刷量
# 急救
# 奇葩
# 香港理工大学
# 0.893309772015
# 科学家
# 中国区
# 尽快
# 办
# 爵迹
# 惊悚
# 帷幕
# 台灯
# 又
# 女子
# 人偷
# 户
# 乡
# 女孩
# 海
# 件
# 此前
# 健
# 模拟

# %%
print vocab.special_words
print vocab.words, '\n'
print vocab.word2id, '\n'
print vocab.wordcount, '\n'
# Out:
# [u'PAD', u'START', u'EOS', u'UNK']
# [u'PAD', u'START', u'EOS', u'UNK', u'\u4e94\u7ebf', u'\u6d77\u5ce1\u4e24\u5cb8', u'\u5965\u8fea', u'\u51fa\u6765', u'\u7b2c\u4e8c', u'\u8fd8\u8981', u'\u95e8\u7968', u'\u9e23\u4eba', u'\u7b2c\u4e94', u'\u4e3a\u4e3b', u'\u79d1\u5728', u'\u4f5c\u5f0a', u'\u4e00\u662f', u'\u5361\u62c9', u'\u94f6\u5b50', u'\u5e78\u8fd0\u661f', u'\u8c08', u'\u7ebf', u'\u9ed1\u8c79', u'\u53cd', u'\u8d22\u653f\u5385', u'\u56f0\u5883', u'0.506884753704', u'\u5e7c\u7ae5', u'\u987b\u77e5', u'\u4e07\u4f59\u5143', u'\u4e16\u7eaa', u'0.599535107613', u'\u8d77\u8bc9', u'\u897f\u85cf', u'\u7ebf\u4e0a', u'\u95f9', u'\u89c1\u9762\u4f1a', u'\u7f8e\u7f57', u'\u53f2\u8bd7', u'\u7b2c\u4e00', u'\u7ecf\u6d4e\u635f\u5931', u'\u7b2c\u4e09', u'\u4e2d\u897f\u533b', u'Max', u'\u5218\u98de', u'\u5e94', u'\u62b1\u4f4f', u'\u516c\u8def', u'\u4e3a\u4e86', u'\u4e09\u5e74', u'\u4e8b\u524d', u'\u56fd\u811a', u'\u903c\u5e73\u6052\u5927', u'AT&T', u'0.470207974315', u'\u515a\u5458\u5e72\u90e8', u'\u94bb\u6212', u'\u4e2d\u5c0f\u57ce\u5e02', u'\u660e\u786e', u'\u5728\u5bb6', u'18183', u'\u7b2c\u516d\u6b21', u'\u753b\u8d28', u'0.926888644695', u'\u7ffb\u8bd1', u'0.847989976406', u'\u4e4b\u65c5', u'\u5f00\u5de5', u'\u6f2b\u6f2b', u'\u65b0\u95fb', u'\u5973\u795e', u'\u63a2\u5e95', u'\u4ea7\u54c1', u'\u987b', u'\u6536\u56de', u'\u76ee\u524d', u'\u4e0a', u'\u540e', u'\u7efc\u827a\u8282\u76ee', u'\u673a\u5236', u'txt', u'\u4e00\u6b21', u'\u6279\u590d', u'0.936728239059', u'\u4e08\u592b', u'\u4f34', u'\u79bb', u'\u636e\u8bf4', u'\u5f00\u5c40', u'\u5468\u672c\u987a', u'\u5c14\u7279', u'\u5c97\u4f4d', u'\u8bca\u7597', u'\u5360\u636e', u'\u5f3a\u8c03', u'\u5f00\u5c55', u'90', u'\u6b63\u5f0f', u'EDG', u'0.061470988724', u'\u8ba1\u59d4', u'\u505a\u51fa', u'\u4e3a\u4f55', u'\u547d\u6848', u'\u7cbe\u51c6', u'0.289149539173', u'\u8282', u'\u94f6\u4ef7', u'\u7231\u60c5', u'\u5e02\u573a\u4e3b\u4f53', u'\u5404\u7ea7', u'\u610f\u89c1', u'\u603b\u7edf', u'\u53f8\u6cd5', u'\u6728\u5730\u677f', u'A', u'0.423862367868', u'\u751f\u7269', u'\u6bd4\u5229\u65f6', u'\u903e', u'\u6807\u7684', u'\u5976\u8336', u'\u5c04\u96d5', u'0.353408247232', u'\u67f3\u5dde', u'\u786b\u9178', u'\u9519\u8bef', u'wins', u'\u901a\u5e38', u'\u738b\u6653\u6668', u'\u53d8\u8d28', u'\u4e00\u680b', u'\u5f3a\u5927', u'\u793e\u533a', u'GSMA', u'\u6316', u'\u6700\u5e05', u'2020', u'\u4e2d\u654f', u'\u6240', u'\u90a3\u4e2a', u'\u8ba2\u9605', u'\u6539\u9020', u'\u57fa\u5730', u'\u6821\u957f', u'\u673a\u5173', u'\u5a92\u4f53', u'\u5728\u5916', u'\u732a\u8089', u'\u7802\u77f3', u'\u9996\u79c0', u'\u8ffd\u56de', u'\u8003\u8bd5\u7f51', u'\u8d8a', u'\u5e15\u91d1\u68ee\u75c5', u'\u7238\u7238', u'0.340383648872', u'\u59dc\u680b', u'\u6709\u5173', u'\u9b54\u6cd5\u5e08', u'\u76ee\u51fb', u'\u5c01\u9876', u'\u7a81\u51fa', u'\u505a\u5230', u'\u7fa4\u4f53', u'\u7535\u52a8\u8f66', u'\u5f00\u5fc3', u'\u61c2', u'\u533b\u6539', u'\u79cb\u666f', u'\u95f0\u571f', u'\u6210\u90fd', u'\u53f8\u673a', u'\u526f\u6821\u957f', u'\u5168\u90e8', u'\u79d2', u'\u5468\u56f4', u'\u8fde', u'0.886992633343', u'\u5e02\u653f\u5e9c', u'\u7fa4\u4f17', u'\u9a7b', u'0.435768723488', u'\u597d', u'\u91cd\u7532\u5957', u'\u5218\u607a\u5a01', u'\u6216', u'176', u'\u7b2c\u4e03\u7248', u'\u75ab\u60c5', u'\u5f02\u5ba2', u'BRAIN', u'\u65af', u'\u529f\u592b', u'0.573544807732', u'\u968f\u540e', u'\u841d\u535c', u'\u5916\u5a92', u'\u7275\u624b', u'\u5f00\u5e55', u'\u89e3\u9664', u'\u7a81\u53d1', u'\u6c88\u90e8', u'\u5404\u7c7b', u'\u5341\u4e8c\u4e94', u'\u5382\u957f', u'\u8ba8\u8bba', u'\u5305\u5bb9', u'\u6674\u5ddd', u'\u300d', u'\u4eb2\u621a', u'\u884c\u9a76', u'\uff13', u'\u5f00\u5ead', u'\u8bb0', u'\u5428\u91cd', u'\u6625\u68a6', u'0.782162070274', u'\u4e0d\u9971\u548c', u'\u5f53', u'\u8d6b\u96f7\u65af', u'\u529e\u516c\u5385', u'\u9a6c\u9f99', u'\u5367\u8695', u'\u5e78\u4e8f', u'\u5185\u7ef4\u5c14', u'\u89e3\u9501', u'\u7ef4\u548c\u90e8\u961f', u'\u5931\u63a7', u'0.83428299427', u'\u601d\u601d', u'\u4e22', u'\u7ae5\u8f66', u'\u5e74\u524d', u'\u673a\u573a', u'\u2018', u'\u5361\u66fc' ...
#
# {u'\u4e94\u7ebf': 4, u'\u6d77\u5ce1\u4e24\u5cb8': 5, u'\u5185\u6d4b': 1877, u'\u5965\u8fea': 6, u'\u8c08': 20, u'\u7b2c\u4e8c': 8, u'\u8fd8\u8981': 9, u'\u9e23\u4eba': 11, u'\u7b2c\u4e94': 12, u'\u4e3a\u4e3b': 13, u'\u79d1\u5728': 14, u'\u4f5c\u5f0a': 15, u'\u59d4\u5458': 1878, u'\u5361\u62c9': 17, u'\u94f6\u5b50': 18, u'\u5e78\u8fd0\u661f': 19, u'\u51fa\u6765': 7, u'\u5965\u8fd0': 2388, u'\u7ebf': 21, u'\u9ed1\u8c79': 22, u'\u53cd': 23, u'\u8d22\u653f\u5385': 24, u'\u56f0\u5883': 25, u'0.506884753704': 26, u'\u987b\u77e5': 28, u'\u8ba2\u9605': 141, u'\u4e07\u4f59\u5143': 29, u'\u4e16\u7eaa': 30, u'0.599535107613': 31, u'\u8d77\u8bc9': 32, u'\u897f\u85cf': 33, u'\u7ebf\u4e0a': 34, u'\u95f9': 35, u'\u89c1\u9762\u4f1a': 36, u'\u7f8e\u7f57': 37, u'\u53f2\u8bd7': 38, u'\u7b2c\u4e00': 39, u'\u7ecf\u6d4e\u635f\u5931': 40, u'\u7b2c\u4e09': 41, u'\u4e2d\u897f\u533b': 42, u'\u5218\u98de': 44, u'\u5e94': 45, u'\u62b1\u4f4f': 46, u'\u516c\u8def': 47, u'\u4e3a\u4e86': 48, u'\u4e09\u5e74': 49, u'\u4e8b\u524d': 50, u'\u56fd\u811a': 51, u'\u903c\u5e73\u6052\u5927': 52, u'AT&T': 53, u'0.470207974315': 54, u'\u515a\u5458\u5e72\u90e8': 55, u'\u5b8b\u831c': 4596, u'\u4e2d\u5c0f\u57ce\u5e02': 57, u'\u660e\u786e': 58, u'\u5728\u5bb6': 59, u'\u7b2c\u516d\u6b21': 61, u'\u753b\u8d28': 62, u'0.951200187206': 300, u'\u7ffb\u8bd1': 64, u'0.847989976406': 65, u'\u4e4b\u65c5': 66, u'\u5f00\u5de5': 67, u'\u6f2b\u6f2b': 68, u'\u65b0\u95fb': 69, u'\u63a2\u5e95': 71, u'\u4ea7\u54c1': 72, u'\u987b': 73, u'\u6536\u56de': 74, u'\u76ee\u524d': 75, u'\u4e0a': 76, u'\u540e': 77, u'\u7efc\u827a\u8282\u76ee': 78, u'\u673a\u5236': 79, u'txt': 80, u'\u4e00\u6b21': 81, u'\u6279\u590d': 82, u'0.936728239059': 83, u'\u4e08\u592b': 84, u'\u4f34': 85, u'\u79bb': 86, u'\u636e\u8bf4': 87, u'\u5f00\u5c40': 88, u'\u5468\u672c\u987a': 89, u'\u5c14\u7279': 90, u'\u5c97\u4f4d': 91, u'\u8bca\u7597': 92, u'\u5360\u636e': 93, u'\u5f00\u5c55': 95, u'90': 96, u'\u6b63\u5f0f': 97, u'EDG': 98, u'0.061470988724': 99, u'\u8ba1\u59d4': 100, u'\u505a\u51fa': 101, u'\u751f\u6d3b\u5708': 491, u'\u547d\u6848': 103, u'\u7cbe\u51c6': 104, u'0.289149539173': 105, u'\u8282': 106, u'\u7231\u60c5': 108, u'\u4fee': 776, u'\u5f00\u7740\u8f66': 551, u'\u5404\u7ea7': 110, u'\u610f\u89c1': 111, u'\u4e00\u6bb5': 573, u'A': 115, u'0.914784312248': 591, u'0.423862367868': 116, u'0.624991794427': 6173, u'\u91d1\u4ef7': 599, u'\u6bd4\u5229\u65f6': 118, u'\u5f1f\u5b50': 612, u'\u6807\u7684': 120, u'\u5976\u8336': 121, u'0.782242655754': 5633, u'\u5c04\u96d5': 122, u'0.353408247232': 123, u'\u9519\u8bef': 126, u'wins': 127, u'\u901a\u5e38': 128, u'\u53d7\u963b': 1805, u'\u738b\u6653\u6668': 129, u'\u4e00\u680b': 131, u'\u5f3a\u5927': 132, u'\u6316': 135, u'\u4e4b\u673a': 706, u'\u9057\u5740': 1150, u'\u4e00\u6837': 741, u'\u8054\u624b': 1221, u'\u6240': 139, u'\u7eba\u7ec7\u5de5\u4e1a': 5193, u'\u8d2d\u7269': 4189, u'\u6539\u9020': 142, u'\u4e00\u6848': 3066, u'\u57fa\u5730': 143, u'\u6821\u957f': 144, u'\u673a\u5173': 145, u'\u5a92\u4f53': 146, u'\u81ed': 809, u'API': 3604, u'\u732a\u8089': 148, u'\u7802\u77f3': 149, u'\u9996\u79c0': 150, u'\u8003\u8bd5\u7f51': 152, u'\u8d8a': 153, u'\u8c03\u67e5\u62a5\u544a': 3246, u'\u7238\u7238': 155, u'0.340383648872': 156, u'\u59dc\u680b': 157, u'\u6709\u5173': 158, u'\u9b54\u6cd5\u5e08': 159, u'\u76ee\u51fb': 160, u'\u5c01\u9876': 161, u'\u7a81\u51fa': 162, u'\u505a\u5230': 163, u'\u7fa4\u4f53': 164, u'\u7535\u52a8\u8f66': 165, u'\u5f00\u5fc3': 166, u'\u61c2': 167, u'\u533b\u6539': 168, u'\u79cb\u666f': 169, u'\u95f0\u571f': 170, u'\u6210\u90fd': 171, u'\u53f8\u673a': 172, u'\u526f\u6821\u957f': 173, u'\u5168\u90e8': 174, u'\u79d2': 175, u'\u5468\u56f4': 176, u'\u8fde': 177, u'0.886992633343': 178, u'\u5e02\u653f\u5e9c': 179, u'\u7fa4\u4f17': 180, u'\u9a7b': 181, u'0.435768723488': 182, u'\u597d': 183, u'\u56db\u5206': 2129, u'\u90a3\u582a': 970, u'\u5973\u5b69\u5b50': 2609, u'\u5218\u607a\u5a01': 185, u'\u6216': 186, u'176': 187, u'\u7b2c\u4e03\u7248': 188, u'0.568164920 ...
#
# {u'\u53bf\u957f': 1, u'\u4e94\u7ebf': 2, u'0.75544077158': 1, u'\u91cd\u7279\u5927': 1, u'\u6d77\u5ce1\u4e24\u5cb8': 4, u'\u670d\u7ae0': 1, u'\u52b1\u5fd7': 1, u'\u5965\u8fea': 2, u'\u6d89': 1, u'\u51fa\u6765': 4, u'\u7b2c\u4e8c': 3, u'\u8fd8\u8981': 5, u'\u6c47\u4f73': 1, u'0.149896198651': 1, u'\u95e8\u7968': 3, u'\u9e23\u4eba': 2, u'\u7b2c\u4e94': 3, u'\u914d': 1, u'0.825499892235': 1, u'\u4e3a\u4e3b': 4, u'0.85087287426': 1, u'\u79d1\u5728': 2, u'0.611813664436': 1, u'\u4f5c\u5f0a': 5, u'0.866712987423': 1, u'0.833901941776': 1, u'0.132236337023': 1, u'0.221964672208': 1, u'\u4e00\u662f': 2, u'0.892921328545': 1, u'0.713099479675': 1, u'\u5361\u62c9': 4, u'\u4fd7\u8bed': 1, u'0.845144033432': 1, u'\u94f6\u5b50': 5, u'\u6d0b\u9152': 1, u'\u7206\u7ea2': 1, u'\u5e78\u8fd0\u661f': 4, u'\u8c08': 2, u'0.323378741741': 1, u'0.213664190844': 1, u'\u5206\u4e2d\u5fc3': 1, u'\u7ebf': 5, u'0.663929651181': 1, u'0.638713911176': 1, u'0.135843797121': 1, u'\u8d34\u7ed8': 1, u'\u9ed1\u8c79': 4, u'\u4e24\u5e74': 1, u'\u53cd': 7, u'\u8d22\u653f\u5385': 2, u'\u5f39\u6027': 1, u'0.146252227681': 1, u'\u56f0\u5883': 2, u'0.506884753704': 2, u'\u5e7c\u7ae5': 2, u'\u987b\u77e5': 2, u'XPS': 1, u'0.752706845601': 1, u'0.510478757322': 1, u'\u5f53\u665a': 1, u'0.637681563695': 1, u'\u4e07\u4f59\u5143': 5, u'0.693670913577': 1, u'0.215386625379': 1, u'0.691862761974': 1, u'0.309376212613': 1, u'\u4e16\u7eaa': 6, u'0.599535107613': 3, u'\u5e73\u5b89': 1, u'\u8d77\u8bc9': 6, u'\u897f\u85cf': 8, u'\u76c8\u5229': 1, u'\u7ebf\u4e0a': 4, u'0.615614533424': 1, u'0.300662010908': 1, u'\u95f9': 2, u'0.757695436478': 1, u'\u89c1\u9762\u4f1a': 2, u'\u79df\u5ba2': 1, u'\u7f8e\u7f57': 2, u'\u4e1a\u754c': 1, u'0.231874679526': 1, u'\u53f2\u8bd7': 6, u'0.97879832983': 1, u'\u7b2c\u4e03': 1, u'\u7b2c\u4e00': 17, u'\u5b89\u76d1': 1, u'0.736764729023': 1, u'0.671751032273': 1, u'\u7ecf\u6d4e\u635f\u5931': 2, u'\u5165\u7761': 1, u'0.605525813997': 1, u'\u7b2c\u4e09': 3, u'\u4e2d\u897f\u533b': 6, u'Max': 2, u'\u8bd5\u56fe': 1, u'\u5218\u98de': 2, u'\u5e94': 3, u'0.386854451274': 1, u'0.934092760086': 1, u'\u773c\u4e2d': 1, u'\u62b1\u4f4f': 2, u'\u6b66\u9675': 1, u'0.486404524744': 1, u'\u4e3a\u4e89': 1, u'\u65e0\u5904': 1, u'\u516c\u8def': 9, u'\u4e3a\u4e86': 14, u'\u4e09\u5e74': 2, u'\u4e8b\u524d': 2, u'\u56fd\u811a': 2, u'0.793963968754': 1, u'0.920194089413': 1, u'0.886030673981': 1, u'0.712006634474': 1, u'0.131801873446': 1, u'\u903c\u5e73\u6052\u5927': 2, u'\u793c\u6559': 1, u'AT&T': 2, u'0.419447083026': 1, u'0.470207974315': 2, u'\u515a\u5458\u5e72\u90e8': 2, u'\u94bb\u6212': 2, u'chint': 1, u'\u4e2d\u5c0f\u57ce\u5e02': 2, u'\u660e\u786e': 4, u'\u5728\u5bb6': 5, u'\u5165\u7720': 1, u'0.882679700851': 1, u'0.311292856932': 1, u'18183': 2, u'\u5e7f\u4e3a\u6d41\u4f20': 1, u'\u7b2c\u516d\u6b21': 4, u'\u753b\u8d28': 2, u'0.160957531205': 1, u'\u6807\u51c6\u7ea7': 1, u'0.230288729072': 1, u'0.926888644695': 3, u'\u7ffb\u8bd1': 2, u'0.847989976406': 2, u'\u4e4b\u65c5': 2, u'\u5f00\u5de5': 5, u'\u6f2b\u6f2b': 2, u'\u65b0\u95fb': 28, u'\u5973\u795e': 4, u'0.142387655564': 1, u'\u4ea4\u8b66\u5927\u961f': 1, u'\u63a2\u5e95': 2, u'\u4ea7\u54c1': 17, u'0.585375274221': 1, u'NOT': 1, u'\u987b': 3, u'0.635701656342': 1, u'\u6536\u56de': 2, u'0.847553133965': 1, u'\u5de8\u4eba': 1, u'0.494206023713': 1, u'Dexter': 1, u'0.748329401016': 1, u'\u76ee\u524d': 28, u'\u4e0a': 93, u'45': 1, u'0.250654548407': 1, u'\u540e': 82, u'\u4ed8\u5174\u542f': 1, u'\u7efc\u827a\u8282\u76ee': 2, u'\u53d1\u80b2': 1, u'0.891190767288': 1, u'0.16319781666': 1, u'0.534873852299': 1, u'\u5e74\u5747': 1, u'\u673a\u5236': 5, u'txt': 2, u'0.799274355173': 1, u'\u987a\u5229\u5b8c\u6210': 1, u'0.85845553875': 1, u'0.929724633694': 1, u'\u4e00\u6b21': 9, u'\u6279\u590d': 3, u'0.458083629608': 1, u'\u7cbe\u70bc\u6cb9': 1, u'\u5e03\u9762': 1, u'\u8f66\u8f86\u6bb5': 1, u'0.695556312799': 1, u'0.748301923275': 1, u'0.936728239059': 2, u'\u66b4\u6da8\u66b4\u8dcc': 1, u'\u4e08\u592b': 3, u'\u7ebf\u4f4d': 1, u'\ ...

# %% [markdown]
# ### orgnize data

# %%
import numpy as np
import random

class Dataset(object):
    def __init__(self, vocabulary, filename, name='dataset', batch_size=3):
        self.name = name
        self.batch_size = batch_size
        self.dataset = np.array([map(vocabulary.sentence_to_word_ids, line.split('\t')[0:2])
                        for line in open(filename, 'r')])
        random.shuffle(self.dataset)
        
    def __len__(self):
        return len(self.dataset)
        
    def __getitem__(self, index):
        assert index >= 0 and index < self.__len__(), 'invalid index'
        return self.dataset[index]
    
    def __iter__(self):
        index = 0
        while index < self.__len__():
            yield self.__getitem__(index)
            index += 1
    
    def next_batch(self):
        indices = [random.randint(0, self.__len__() - 1) for i in range(self.batch_size)]
        return self.dataset[indices]
# Out:
# <__main__.Dataset object at 0x7fcf08f46550>

# %%
print dataset.batch_size
# Out:
# 3

# %%
dataset = Dataset(vocab, 'small.txt')
print dataset, '\n'

print type(dataset[0])
print dataset[0], '\n'

print type(dataset.next_batch())
print dataset.next_batch()
# Out:
# <__main__.Dataset object at 0x7fcf08366a50>
#
# <type 'numpy.ndarray'>
# [list([609, 3, 597, 609, 225, 3, 3, 3, 3, 3, 427, 248, 3, 3, 312])
#  list([3, 574, 3, 60, 3, 597, 571, 225, 3, 3, 3, 3, 3, 570, 3, 3, 427, 574, 3, 3, 3, 252, 410, 255, 3, 334, 3, 11, 225, 3, 574, 244, 404, 3, 3, 555, 406, 3, 3])]
#
# <type 'numpy.ndarray'>
# [[ list([573, 3, 574, 441, 351, 3, 252, 3, 574, 3, 3, 557, 252, 3, 3, 368, 3, 3, 513, 557, 323, 3, 3, 143, 3, 574, 662, 659, 3, 3, 3, 3])
#   list([3, 355, 574, 441, 252, 3, 3, 557, 252, 3, 3, 180, 3, 3, 574, 441, 3, 351, 3, 3, 3, 252, 3])]
#  [list([146, 492, 12, 10, 3, 3, 3, 248, 3, 3, 3, 3])
#   list([3, 144, 3, 60, 492, 12, 10, 410, 362, 3, 3, 571, 570, 3, 3, 277, 480, 3, 10, 574, 137, 3, 252, 146, 60, 492, 12, 10, 410, 362, 3, 3, 571, 79, 13, 3, 574, 3, 216, 3, 252, 459, 117, 99, 3, 99, 3, 99, 546, 99, 3, 99, 3, 117, 99, 3, 3, 574, 283, 570, 3, 3, 404, 3, 469, 252, 3, 99, 3, 99, 3, 99, 3, 99, 3, 99, 3, 99, 3, 99, 3, 99, 591, 3, 99, 3, 390, 3, 12, 10, 34, 3, 3])]
#  [list([665, 3, 66, 349, 3, 3, 132, 198, 153, 478, 587, 3, 252, 3, 3, 513])
#   list([587, 3, 3, 252, 335, 574, 665, 3, 66, 349, 3, 153, 60, 3, 3, 3, 571, 3, 3, 13, 212, 382, 574, 3, 618, 3, 649, 570, 3, 3, 151, 330, 237, 581, 252, 583, 294, 382, 574, 542, 158, 574, 665, 3, 66, 349, 3, 3, 3, 509, 132, 198, 153, 587, 3, 252, 3, 3])]]
